# %% [markdown]
# <a href="https://colab.research.google.com/github/mostafa-ja/Data-Mining-fall-2023/blob/main/Data_Mining1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ydata-profiling[notebook]==4.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.5/344.5 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 45.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 100.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 15.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 54.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 73.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 30.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 1.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import ydata_profiling as pp
# Out:
# /usr/local/lib/python3.10/dist-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/visions/backends/shared/nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:

# %%
tree = ET.parse('/content/post.xml')
root = tree.getroot()

# Now, 'root' contains the XML structure, and you can access and manipulate it programmatically.

# %% [markdown]
# 4 lines of the file for initial analysis
#
# ```
# <row Id="4" PostTypeId="1" AcceptedAnswerId="7" CreationDate="2008-07-31T21:42:52.667" Score="322" ViewCount="21888" Body="&lt;p&gt;I want to use a track-bar to change a form's opacity.&lt;/p&gt;&#xA;&#xA;&lt;p&gt;This is my code:&lt;/p&gt;&#xA;&#xA;&lt;pre&gt;&lt;code&gt;decimal trans = trackBar1.Value / 5000;&#xA;this.Opacity = trans;&#xA;&lt;/code&gt;&lt;/pre&gt;&#xA;&#xA;&lt;p&gt;When I try to build it, I get this error:&lt;/p&gt;&#xA;&#xA;&lt;blockquote&gt;&#xA;  &lt;p&gt;Cannot implicitly convert type 'decimal' to 'double'.&lt;/p&gt;&#xA;&lt;/blockquote&gt;&#xA;&#xA;&lt;p&gt;I tried making &lt;code&gt;trans&lt;/code&gt; a &lt;code&gt;double&lt;/code&gt;, but then the control doesn't work. This code has worked fine for me in VB.NET in the past. &lt;/p&gt;&#xA;" OwnerUserId="8" LastEditorUserId="451518" LastEditorDisplayName="Rich B" LastEditDate="2014-07-28T10:02:50.557" LastActivityDate="2014-12-20T17:18:47.807" Title="When setting a form's opacity should I use a decimal or double?" Tags="&lt;c#&gt;&lt;winforms&gt;&lt;type-conversion&gt;&lt;opacity&gt;" AnswerCount="13" CommentCount="1" FavoriteCount="27" CommunityOwnedDate="2012-10-31T16:42:47.213" />
#   <row Id="6" PostTypeId="1" AcceptedAnswerId="31" CreationDate="2008-07-31T22:08:08.620" Score="140" ViewCount="10912" Body="&lt;p&gt;I have an absolutely positioned &lt;code&gt;div&lt;/code&gt; containing several children, one of which is a relatively positioned &lt;code&gt;div&lt;/code&gt;. When I use a &lt;strong&gt;percentage-based width&lt;/strong&gt; on the child &lt;code&gt;div&lt;/code&gt;, it collapses to &lt;code&gt;0&lt;/code&gt; width on IE7, but not on Firefox or Safari. &lt;/p&gt;&#xA;&#xA;&lt;p&gt;If I use &lt;strong&gt;pixel width&lt;/strong&gt;, it works. If the parent is relatively positioned, the percentage width on the child works. &lt;/p&gt;&#xA;&#xA;&lt;p&gt;Is there something I'm missing here? &#xA;Is there an easy fix for this besides the &lt;em&gt;pixel-based width&lt;/em&gt; on the child? &#xA;Is there an area of the &lt;code&gt;CSS&lt;/code&gt; specification that covers this?&lt;/p&gt;&#xA;" OwnerUserId="9" LastEditorUserId="1350209" LastEditorDisplayName="Rich B" LastEditDate="2014-06-26T04:57:13.750" LastActivityDate="2014-10-10T05:55:36.033" Title="Why doesn't the percentage width child in absolutely positioned parent work?" Tags="&lt;html&gt;&lt;css&gt;&lt;css3&gt;&lt;internet-explorer-7&gt;" AnswerCount="5" CommentCount="0" FavoriteCount="7" />
#   <row Id="7" PostTypeId="2" ParentId="4" CreationDate="2008-07-31T22:17:57.883" Score="242" Body="&lt;p&gt;An explicit cast to double isn't necessary.&lt;/p&gt;&#xA;&#xA;&lt;pre&gt;&lt;code&gt;double trans = (double)trackBar1.Value / 5000.0;&#xA;&lt;/code&gt;&lt;/pre&gt;&#xA;&#xA;&lt;p&gt;Identifying the constant as &lt;code&gt;5000.0&lt;/code&gt; (or as &lt;code&gt;5000d&lt;/code&gt;) is sufficient:&lt;/p&gt;&#xA;&#xA;&lt;pre&gt;&lt;code&gt;double trans = trackBar1.Value / 5000.0;&#xA;double trans = trackBar1.Value / 5000d;&#xA;&lt;/code&gt;&lt;/pre&gt;&#xA;" OwnerUserId="9" LastEditorUserId="967315" LastEditDate="2012-10-14T11:50:16.703" LastActivityDate="2012-10-14T11:50:16.703" CommentCount="0" />
#   <row Id="9" PostTypeId="1" AcceptedAnswerId="1404" CreationDate="2008-07-31T23:40:59.743" Score="862" ViewCount="223405" Body="&lt;p&gt;Given a &lt;code&gt;DateTime&lt;/code&gt; representing a person's birthday, how do I calculate their age?  &lt;/p&gt;&#xA;" OwnerUserId="1" LastEditorUserId="1620220" LastEditorDisplayName="Rich B" LastEditDate="2015-01-15T21:43:12.603" LastActivityDate="2015-02-17T17:24:51.690" Title="How do I calculate someone's age in C#?" Tags="&lt;c#&gt;&lt;.net&gt;&lt;datetime&gt;" AnswerCount="48" CommentCount="5" FavoriteCount="256" CommunityOwnedDate="2011-08-16T19:40:43.080" />
# ```

# %%
# print first row with its fields

for post in root.findall('row'):
    post_attributes = {
        'id': post.get('Id'),
        'PostTypeId': post.get('PostTypeId'),
        'ParentId': post.get('ParentId'),
        'AcceptedAnswerId': post.get('AcceptedAnswerId'),
        'creation_date': post.get('CreationDate'),
        'score': post.get('Score'),
        'ViewCount': post.get('ViewCount'),
        'body': post.get('Body'),
        'OwnerUserId': post.get('OwnerUserId'),
        'LastEditorUserId': post.get('LastEditorUserId'),
        'LastEditorDisplayName': post.get('LastEditorDisplayName'),
        'LastEditDate': post.get('LastEditDate'),
        'LastActivityDate': post.get('LastActivityDate'),
        'Title': post.get('Title'),
        'Tags': post.get('Tags'),
        'AnswerCount': post.get('AnswerCount'),
        'CommentCount': post.get('CommentCount'),
        'FavoriteCount': post.get('FavoriteCount'),
        'CommunityOwnedDate': post.get('CommunityOwnedDate')
    }

    # Print or process these values as needed
    for key, value in post_attributes.items():
        print(f"{key}: {value}")
    print("\n")  # Add a new line after each post's attributes
    break  # Breaking after the first post, remove this if you want to iterate through all posts
# Out:
# id: 4
# PostTypeId: 1
# ParentId: None
# AcceptedAnswerId: 7
# creation_date: 2008-07-31T21:42:52.667
# score: 322
# ViewCount: 21888
# body: <p>I want to use a track-bar to change a form's opacity.</p>
#
# <p>This is my code:</p>
#
# <pre><code>decimal trans = trackBar1.Value / 5000;
# this.Opacity = trans;
# </code></pre>
#
# <p>When I try to build it, I get this error:</p>
#
# <blockquote>
#   <p>Cannot implicitly convert type 'decimal' to 'double'.</p>
# </blockquote>
#
# <p>I tried making <code>trans</code> a <code>double</code>, but then the control doesn't work. This code has worked fine for me in VB.NET in the past. </p>
#
# OwnerUserId: 8
# LastEditorUserId: 451518
# LastEditorDisplayName: Rich B
# LastEditDate: 2014-07-28T10:02:50.557
# LastActivityDate: 2014-12-20T17:18:47.807
# Title: When setting a form's opacity should I use a decimal or double?
# Tags: <c#><winforms><type-conversion><opacity>
# AnswerCount: 13
# CommentCount: 1
# FavoriteCount: 27
# ...

# %%
#create a pandas dataframe from the file

# Initialize empty lists to store data
ids = []
post_types = []
ParentId = []
accepted_answer_ids = []
creation_dates = []
scores = []
view_counts = []
bodies = []
owner_user_ids = []
last_editor_user_ids = []
last_editor_display_names = []
last_edit_dates = []
last_activity_dates = []
titles = []
tags = []
answer_counts = []
comment_counts = []
favorite_counts = []
community_owned_dates = []

for post in root.findall('row'):
    ids.append(post.get('Id'))
    post_types.append(post.get('PostTypeId'))
    ParentId.append(post.get('ParentId'))
    accepted_answer_ids.append(post.get('AcceptedAnswerId'))
    creation_dates.append(post.get('CreationDate'))
    scores.append(post.get('Score'))
    view_counts.append(post.get('ViewCount'))
    bodies.append(post.get('Body'))
    owner_user_ids.append(post.get('OwnerUserId'))
    last_editor_user_ids.append(post.get('LastEditorUserId'))
    last_editor_display_names.append(post.get('LastEditorDisplayName'))
    last_edit_dates.append(post.get('LastEditDate'))
    last_activity_dates.append(post.get('LastActivityDate'))
    titles.append(post.get('Title'))
    tags.append(post.get('Tags'))
    answer_counts.append(post.get('AnswerCount'))
    comment_counts.append(post.get('CommentCount'))
    favorite_counts.append(post.get('FavoriteCount'))
    community_owned_dates.append(post.get('CommunityOwnedDate'))

# Create a DataFrame using the lists
data = {
    'id': ids,
    'PostTypeId': post_types,
    'ParentId': ParentId,
    'AcceptedAnswerId': accepted_answer_ids,
    'CreationDate': creation_dates,
    'Score': scores,
    'ViewCount': view_counts,
    'Body': bodies,
    'OwnerUserId': owner_user_ids,
    'LastEditorUserId': last_editor_user_ids,
    'LastEditorDisplayName': last_editor_display_names,
    'LastEditDate': last_edit_dates,
    'LastActivityDate': last_activity_dates,
    'Title': titles,
    'Tags': tags,
    'AnswerCount': answer_counts,
    'CommentCount': comment_counts,
    'FavoriteCount': favorite_counts,
    'CommunityOwnedDate': community_owned_dates
}

df = pd.DataFrame(data)

# Display the DataFrame
print(df.head())  # Show the first few rows
# Out:
#    id PostTypeId ParentId AcceptedAnswerId             CreationDate Score  \
# 0   4          1     None                7  2008-07-31T21:42:52.667   322
# 1   6          1     None               31  2008-07-31T22:08:08.620   140
# 2   7          2        4             None  2008-07-31T22:17:57.883   242
# 3   9          1     None             1404  2008-07-31T23:40:59.743   862
# 4  11          1     None             1248  2008-07-31T23:55:37.967   817
#
#   ViewCount                                               Body OwnerUserId  \
# 0     21888  <p>I want to use a track-bar to change a form'...           8
# 1     10912  <p>I have an absolutely positioned <code>div</...           9
# 2      None  <p>An explicit cast to double isn't necessary....           9
# 3    223405  <p>Given a <code>DateTime</code> representing ...           1
# 4     89203  <p>Given a specific <code>DateTime</code> valu...           1
#
#   LastEditorUserId LastEditorDisplayName             LastEditDate  \
# ...

# %%
df.describe()
# Out:
#          id PostTypeId ParentId AcceptedAnswerId             CreationDate  \
# count   221        221      150               58                      221
# unique  221          2       62               58                      221
# top       4          2      126                7  2008-07-31T21:42:52.667
# freq      1        150        7                1                        1
#
#        Score ViewCount                                               Body  \
# count    221        71                                                221
# unique    80        71                                                221
# top        3     21888  <p>I want to use a track-bar to change a form'...
# freq      15         1                                                  1
#
#        OwnerUserId LastEditorUserId LastEditorDisplayName  \
# count          215              143                    93
# unique          81               89                    60
# ...

# %%
# Count the number of null values in each column
null_counts = df.isnull().sum()

# Display the count of null values for each column
print(null_counts)
# Out:
# id                         0
# PostTypeId                 0
# ParentId                  71
# AcceptedAnswerId         163
# CreationDate               0
# Score                      0
# ViewCount                150
# Body                       0
# OwnerUserId                6
# LastEditorUserId          78
# LastEditorDisplayName    128
# LastEditDate              73
# LastActivityDate           0
# Title                    150
# Tags                     150
# AnswerCount              150
# CommentCount               0
# FavoriteCount            159
# CommunityOwnedDate       203
# dtype: int64

# %% [markdown]
# # Question Analysis

# %% [markdown]
# PostTypeId field :
#
# 1=Questions
#
# 2=Answers

# %%
df_question = df[df['PostTypeId'] == '1']

df_question.head(1)
# Out:
#   id PostTypeId ParentId AcceptedAnswerId             CreationDate Score  \
# 0  4          1     None                7  2008-07-31T21:42:52.667   322
#
#   ViewCount                                               Body OwnerUserId  \
# 0     21888  <p>I want to use a track-bar to change a form'...           8
#
#   LastEditorUserId LastEditorDisplayName             LastEditDate  \
# 0           451518                Rich B  2014-07-28T10:02:50.557
#
#           LastActivityDate                                              Title  \
# 0  2014-12-20T17:18:47.807  When setting a form's opacity should I use a d...
#
#                                        Tags AnswerCount CommentCount  \
# 0  <c#><winforms><type-conversion><opacity>          13            1
#
#   FavoriteCount       CommunityOwnedDate
# 0            27  2012-10-31T16:42:47.213

# %%
df_question[df_question['AcceptedAnswerId'].isnull()]

# %%
# Convert values to 0 if null, 1 if not null
df_question['AcceptedAnswerId'] = df_question['AcceptedAnswerId'].notnull().astype(int)
# Out:
# <ipython-input-103-a220ce3d7cd7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_question['AcceptedAnswerId'] = df_question['AcceptedAnswerId'].notnull().astype(int)

# %%
# Convert values to 0 if null, 1 if not null
df_question['CommunityOwnedDate'] = df_question['CommunityOwnedDate'].notnull().astype(int)
# Out:
# <ipython-input-104-1fac6989566c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_question['CommunityOwnedDate'] = df_question['CommunityOwnedDate'].notnull().astype(int)

# %%
#df_question.drop('ParentId', axis=1, inplace=True)
df_question.drop(columns=['PostTypeId','ParentId','OwnerUserId', 'LastEditorUserId', 'LastEditorDisplayName','LastEditDate', 'LastActivityDate'], inplace=True)
# Out:
# <ipython-input-105-766e51db84cf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_question.drop(columns=['PostTypeId','ParentId','OwnerUserId', 'LastEditorUserId', 'LastEditorDisplayName','LastEditDate', 'LastActivityDate'], inplace=True)

# %%
df_question['BodyLength']  = df_question['Body'].str.len()
df_question['TitleLength']  = df_question['Title'].str.len()
# Out:
# <ipython-input-106-cb43fd0f1a1e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_question['BodyLength']  = df_question['Body'].str.len()
# <ipython-input-106-cb43fd0f1a1e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_question['TitleLength']  = df_question['Title'].str.len()

# %%
df_question['CreationDate'] = pd.to_datetime(df_question['CreationDate'])
# Out:
# <ipython-input-107-7c3cc8cd47d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_question['CreationDate'] = pd.to_datetime(df_question['CreationDate'])

# %%
df_question.columns
# Out:
# Index(['id', 'AcceptedAnswerId', 'CreationDate', 'Score', 'ViewCount', 'Body',
#        'Title', 'Tags', 'AnswerCount', 'CommentCount', 'FavoriteCount',
#        'CommunityOwnedDate', 'BodyLength', 'TitleLength'],
#       dtype='object')

# %%
columns_to_convert = ['id','Score', 'ViewCount', 'AnswerCount', 'CommentCount', 'FavoriteCount']
for col in columns_to_convert:
    df_question[col] = df_question[col].fillna(0).astype(int)
# Out:
# <ipython-input-109-71604080adbd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_question[col] = df_question[col].fillna(0).astype(int)

# %%
# Count the number of null values in each column
null_counts = df_question.isnull().sum()

# Display the count of null values for each column
print(null_counts)
# Out:
# id                    0
# AcceptedAnswerId      0
# CreationDate          0
# Score                 0
# ViewCount             0
# Body                  0
# Title                 0
# Tags                  0
# AnswerCount           0
# CommentCount          0
# FavoriteCount         0
# CommunityOwnedDate    0
# BodyLength            0
# TitleLength           0
# dtype: int64

# %%
df_question['Tags'][:10]
# Out:
# 0              <c#><winforms><type-conversion><opacity>
# 1                <html><css><css3><internet-explorer-7>
# 3                                  <c#><.net><datetime>
# 4                                        <c#><datediff>
# 6             <html><browser><timezone><timezoneoffset>
# 7                                                <.net>
# 8                    <c#><linq><web-services><.net-3.5>
# 9          <mysql><database><binary-data><data-storage>
# 11    <performance><algorithm><language-agnostic><un...
# 14                          <mysql><database><triggers>
# Name: Tags, dtype: object

# %%
df_question['Title'][:10]
# Out:
# 0     When setting a form's opacity should I use a d...
# 1     Why doesn't the percentage width child in abso...
# 3               How do I calculate someone's age in C#?
# 4                     How do I calculate relative time?
# 6                    Determining a web user's time zone
# 7     Difference between Math.Floor() and Math.Trunc...
# 8     Filling a DataSet or DataTable from a LINQ que...
# 9                                  Binary Data in MySQL
# 11       What is the fastest way to get the value of π?
# 14                    Throw an error in a MySQL trigger
# Name: Title, dtype: object

# %%
df_question['AcceptedAnswerId'][:10]
# Out:
# 0     1
# 1     1
# 3     1
# 4     1
# 6     1
# 7     0
# 8     1
# 9     1
# 11    1
# 14    1
# Name: AcceptedAnswerId, dtype: int64

# %%
profile = pp.ProfileReport(df_question)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.0.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-11-18 16:35:09.887715&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df_question.columns
# Out:
# Index(['id', 'AcceptedAnswerId', 'CreationDate', 'Score', 'ViewCount', 'Body',
#        'Title', 'Tags', 'AnswerCount', 'CommentCount', 'FavoriteCount',
#        'CommunityOwnedDate', 'BodyLength', 'TitleLength'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df_question[['AcceptedAnswerId','ViewCount','AnswerCount','CommentCount','FavoriteCount','CommunityOwnedDate','BodyLength','TitleLength']].corrwith(df_question['Score'])

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix.to_frame(), annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap with Column A')
plt.show()

# %%
# Drop the column to ignore
column_to_ignore = ['id','AcceptedAnswerId','CommunityOwnedDate','Body','Title', 'Tags']
columns_except_ignored = df_question.drop(columns=column_to_ignore)

# Calculate correlation matrix
correlation_matrix = columns_except_ignored.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap (Ignoring ColumnToIgnore)')
plt.show()
# Out:
# <ipython-input-119-bf49a5427763>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = columns_except_ignored.corr()

# %% [markdown]
# # Answer Analysis

# %%
df_answer = df[df['PostTypeId'] == '2']

df_answer.head(3)
# Out:
#     id PostTypeId ParentId AcceptedAnswerId             CreationDate Score  \
# 2    7          2        4             None  2008-07-31T22:17:57.883   242
# 5   12          2       11             None  2008-07-31T23:56:41.303   240
# 10  18          2       17             None  2008-08-01T05:12:44.193    22
#
#    ViewCount                                               Body OwnerUserId  \
# 2       None  <p>An explicit cast to double isn't necessary....           9
# 5       None  <p>Well, here's how we do it on Stack Overflow...           1
# 10      None  <p>For a table like this:</p>\n\n<pre><code>CR...        None
#
#    LastEditorUserId LastEditorDisplayName             LastEditDate  \
# 2            967315                  None  2012-10-14T11:50:16.703
# 5           1420197            GateKiller  2014-02-18T14:19:35.770
# 10            63550           Jeff Atwood  2013-01-05T14:44:25.013
#
#            LastActivityDate Title  Tags AnswerCount CommentCount  \
# ...

# %%
# Count the number of null values in each column
null_counts = df_answer.isnull().sum()

# Display the count of null values for each column
print(null_counts)
# Out:
# id                         0
# PostTypeId                 0
# ParentId                   0
# AcceptedAnswerId         150
# CreationDate               0
# Score                      0
# ViewCount                150
# Body                       0
# OwnerUserId                4
# LastEditorUserId          75
# LastEditorDisplayName    116
# LastEditDate              73
# LastActivityDate           0
# Title                    150
# Tags                     150
# AnswerCount              150
# CommentCount               0
# FavoriteCount            150
# CommunityOwnedDate       139
# dtype: int64

# %%
df_answer.columns
# Out:
# Index(['id', 'PostTypeId', 'ParentId', 'AcceptedAnswerId', 'CreationDate',
#        'Score', 'ViewCount', 'Body', 'OwnerUserId', 'LastEditorUserId',
#        'LastEditorDisplayName', 'LastEditDate', 'LastActivityDate', 'Title',
#        'Tags', 'AnswerCount', 'CommentCount', 'FavoriteCount',
#        'CommunityOwnedDate'],
#       dtype='object')

# %%
df_answer.drop(columns=['PostTypeId','AcceptedAnswerId','ViewCount','OwnerUserId', 'LastEditorUserId','LastEditorDisplayName', 'LastEditDate', 'LastActivityDate','Title','Tags','AnswerCount','FavoriteCount'], inplace=True)
# Out:
# <ipython-input-123-49fb712c8551>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_answer.drop(columns=['PostTypeId','AcceptedAnswerId','ViewCount','OwnerUserId', 'LastEditorUserId','LastEditorDisplayName', 'LastEditDate', 'LastActivityDate','Title','Tags','AnswerCount','FavoriteCount'], inplace=True)

# %%
# Count the number of null values in each column
null_counts = df_answer.isnull().sum()

# Display the count of null values for each column
print(null_counts)
# Out:
# id                      0
# ParentId                0
# CreationDate            0
# Score                   0
# Body                    0
# CommentCount            0
# CommunityOwnedDate    139
# dtype: int64

# %%
# Convert values to 0 if null, 1 if not null
df_answer['CommunityOwnedDate'] = df_answer['CommunityOwnedDate'].notnull().astype(int)
# Out:
# <ipython-input-125-aa04604ab560>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_answer['CommunityOwnedDate'] = df_answer['CommunityOwnedDate'].notnull().astype(int)

# %%
df_answer['CreationDate'] = pd.to_datetime(df_answer['CreationDate'])
# Out:
# <ipython-input-126-923ff58bc2d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_answer['CreationDate'] = pd.to_datetime(df_answer['CreationDate'])

# %%
df_answer['BodyLength']  = df_answer['Body'].str.len()
# Out:
# <ipython-input-127-02b6ff501999>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_answer['BodyLength']  = df_answer['Body'].str.len()

# %%
# Count the number of null values in each column
null_counts = df_answer.isnull().sum()

# Display the count of null values for each column
print(null_counts)
# Out:
# id                    0
# ParentId              0
# CreationDate          0
# Score                 0
# Body                  0
# CommentCount          0
# CommunityOwnedDate    0
# BodyLength            0
# dtype: int64

# %%
columns_to_convert = ['id','ParentId','Score','CommentCount']
for col in columns_to_convert:
    df_answer[col] = df_answer[col].fillna(0).astype(int)
# Out:
# <ipython-input-134-f2d5c536bb40>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_answer[col] = df_answer[col].fillna(0).astype(int)
