# %% [markdown]
# <a href="https://colab.research.google.com/github/mostafa-ja/Data-Mining-fall-2023/blob/main/data_mining4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost
# !pip install seaborn
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %% [markdown]
# # Download data

# %%
import gdown

file_id = '1quMzXrCUCVTHaVTAT26jO-T_HnhSBxtp'

download_link = f'https://drive.google.com/uc?id={file_id}'
output = 'EX_2.zip'
gdown.download(download_link, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1quMzXrCUCVTHaVTAT26jO-T_HnhSBxtp
# To: /content/EX_2.zip
# 100%|██████████| 125M/125M [00:02<00:00, 46.6MB/s]
# 'EX_2.zip'

# %%
# !unzip '/content/EX_2.zip' -d "/content/data/"
# Out:
# Archive:  /content/EX_2.zip
#   inflating: /content/data/Answer.rar
#   inflating: /content/data/Q_A.rar
#   inflating: /content/data/Questions.rar
#   inflating: /content/data/U.rar
#   inflating: /content/data/tags.rar
#   inflating: /content/data/user_badge.rar

# %%
# !unrar x "/content/data/*.rar"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/data/Questions.rar
#
#   OK
#
# Extracting from /content/data/user_badge.rar
#
#   OK
#
# Extracting from /content/data/Q_A.rar
#
#   OK
#
# Extracting from /content/data/U.rar
#
#   OK
#
# Extracting from /content/data/Answer.rar
#
#   OK
#
# Extracting from /content/data/tags.rar
#
#   OK
# All OK

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load datasets

# %%
answers = pd.read_csv('/content/Answer.csv', encoding="utf-16")
answers = answers.drop(0) # remove the meaningless row(the second line)
answers.head(10)
# Out:
#      Id                   CreationDate  Score  OwnerUserId  CommentCount  \
# 1   127  2008-08-01 16:13:47.600000000   37.0         35.0           2.0
# 2   128  2008-08-01 16:19:04.283000000    7.0         26.0           2.0
# 3   133  2008-08-01 16:31:43.430000000    0.0         59.0           1.0
# 4   139  2008-08-01 16:43:30.880000000    5.0         72.0           0.0
# 5   142  2008-08-01 16:56:55.830000000    2.0         42.0           0.0
# 6   143  2008-08-01 17:01:27.240000000    3.0         86.0           0.0
# 7   169  2008-08-01 18:23:59.040000000   30.0         93.0           0.0
# 8   183  2008-08-01 18:51:12.090000000   35.0         86.0           0.0
# 9   186  2008-08-01 19:07:59.480000000    2.0         40.0           0.0
# 10  190  2008-08-01 19:21:57.517000000    4.0         55.0           0.0
#
#     ClosedDate
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN

# %%
len(answers['ClosedDate'].dropna())
# Out:
# 0

# %%
questions = pd.read_csv('/content/Questions.txt', encoding="utf-16")
questions.head(3)
# Out:
#     Id         CreationDate  Score  ViewCount  OwnerUserId  CommentCount  \
# 0  123  2008-08-01 16:08:52     48      44161         78.0             3
# 1  126  2008-08-01 16:10:30     33       6357         58.0             0
# 2  382  2008-08-02 08:58:28     28       6827        122.0             1
#
#             ClosedDate  FavoriteCount
# 0                  NaN             13
# 1  2012-05-08 18:11:27              2
# 2                  NaN              4

# %%
Q_A = pd.read_csv('/content/Q_A.csv', encoding="utf-16")
Q_A.head(3)
# Out:
#         QId       AId  accepted
# 0    898405   1153025         0
# 1  12679343  12679433         0
# 2  19108614  19786664         0

# %%
Q_A[Q_A['accepted']==1]
# Out:
#               QId       AId  accepted
# 7         9371288   9371326         1
# 8        23613344  23613857         1
# 9        24660822  24702541         1
# 10        6859287   6860105         1
# 18       13988691  13990370         1
# ...           ...       ...       ...
# 1597492  14586647  14612066         1
# 1597498  16558302  16558462         1
# 1597504  14422160  14422297         1
# 1597506  25098589  25098679         1
# 1597508   6654671   6654696         1
#
# [452198 rows x 3 columns]

# %%
users = pd.read_csv('/content/U.csv', encoding="utf-16")
users.head(3)
# Out:
#    Id  Reputation   Views  UpVotes  DownVotes
# 0   1       33107  173080     3225       1299
# 1   3       10145   18988     5654        100
# 2   9        8716    3152       42          4

# %%
user_badge = pd.read_csv('/content/user_badge.txt', encoding="utf-16")
user_badge.head(10)
# Out:
#    UserId     Name
# 0    3718  Teacher
# 1     994  Teacher
# 2    3893  Teacher
# 3    4591  Teacher
# 4    5196  Teacher
# 5    2635  Teacher
# 6    1113  Teacher
# 7    4182  Teacher
# 8     164  Teacher
# 9     652  Teacher

# %%
tags = pd.read_csv('/content/tags.txt', sep='\t')
tags.head(10)
# Out:
#          Id            Tags
# 0   2288942  user-interface
# 1   4433442          canvas
# 2   6381190        shortcut
# 3  27466868        jboss7.x
# 4   8375328            math
# 5   9530883             cdi
# 6  14851537            jdbc
# 7  16153458         eclipse
# 8   4400311              go
# 9   7001897     viewflipper

# %%
len(questions)
# Out:
# 810071

# %%
len(answers)
# Out:
# 1510812

# %%
merged_A_Q = pd.merge(answers, Q_A, left_on='Id', right_on='AId', how='inner')
merged_A_Q = pd.merge(merged_A_Q, questions, left_on='QId', right_on='Id', how='inner',suffixes=('_A', '_Q'))
merged_A_Q.head()
# Out:
#    Id_A                 CreationDate_A  Score_A  OwnerUserId_A  \
# 0   127  2008-08-01 16:13:47.600000000     37.0           35.0
# 1   128  2008-08-01 16:19:04.283000000      7.0           26.0
# 2   139  2008-08-01 16:43:30.880000000      5.0           72.0
# 3   142  2008-08-01 16:56:55.830000000      2.0           42.0
# 4   143  2008-08-01 17:01:27.240000000      3.0           86.0
#
#    CommentCount_A  ClosedDate_A  QId  AId  accepted  Id_Q  \
# 0             2.0           NaN  126  127         1   126
# 1             2.0           NaN  126  128         0   126
# 2             0.0           NaN  126  139         0   126
# 3             0.0           NaN  126  142         0   126
# 4             0.0           NaN  126  143         0   126
#
#         CreationDate_Q  Score_Q  ViewCount  OwnerUserId_Q  CommentCount_Q  \
# 0  2008-08-01 16:10:30       33       6357           58.0               0
# 1  2008-08-01 16:10:30       33       6357           58.0               0
# 2  2008-08-01 16:10:30       33       6357           58.0               0
# 3  2008-08-01 16:10:30       33       6357           58.0               0
# 4  2008-08-01 16:10:30       33       6357           58.0               0
#
#           ClosedDate_Q  FavoriteCount
# 0  2012-05-08 18:11:27              2
# 1  2012-05-08 18:11:27              2
# 2  2012-05-08 18:11:27              2
# 3  2012-05-08 18:11:27              2
# 4  2012-05-08 18:11:27              2

# %%
len(merged_A_Q)
# Out:
# 1510812

# %%
merged_A_Q_U = pd.merge(merged_A_Q, users,  left_on='OwnerUserId_A', right_on='Id', how='inner')
merged_A_Q_U.head()
# Out:
#     Id_A                 CreationDate_A  Score_A  OwnerUserId_A  \
# 0    127  2008-08-01 16:13:47.600000000     37.0           35.0
# 1   3886  2008-08-06 19:29:24.427000000    133.0           35.0
# 2  11567  2008-08-14 19:26:35.570000000      1.0           35.0
# 3  19904  2008-08-21 13:37:58.600000000    135.0           35.0
# 4  26311  2008-08-25 16:01:58.660000000     20.0           35.0
#
#    CommentCount_A  ClosedDate_A    QId    AId  accepted   Id_Q  ... ViewCount  \
# 0             2.0           NaN    126    127         1    126  ...      6357
# 1             1.0           NaN   3881   3886         1   3881  ...     61344
# 2             0.0           NaN  11561  11567         0  11561  ...     16785
# 3             0.0           NaN  19893  19904         1  19893  ...     49130
# 4             7.0           NaN  26305  26311         0  26305  ...    155132
#
#    OwnerUserId_Q  CommentCount_Q         ClosedDate_Q  FavoriteCount  Id  \
# 0           58.0               0  2012-05-08 18:11:27              2  35
# 1          122.0               3                  NaN             72  35
# 2         1310.0               0                  NaN              4  35
# 3         1288.0               1                  NaN             18  35
# 4         2644.0               1                  NaN             43  35
#
#    Reputation  Views  UpVotes  DownVotes
# 0       11543   1060      436        208
# 1       11543   1060      436        208
# 2       11543   1060      436        208
# 3       11543   1060      436        208
# 4       11543   1060      436        208
#
# [5 rows x 22 columns]

# %%
len(merged_A_Q_U)
# Out:
# 1503487

# %%
merged_A_Q_U2 = pd.merge(merged_A_Q, users,  left_on='OwnerUserId_A', right_on='Id', how='left')
merged_A_Q_U2.head()
# Out:
#    Id_A                 CreationDate_A  Score_A  OwnerUserId_A  \
# 0   127  2008-08-01 16:13:47.600000000     37.0           35.0
# 1   128  2008-08-01 16:19:04.283000000      7.0           26.0
# 2   139  2008-08-01 16:43:30.880000000      5.0           72.0
# 3   142  2008-08-01 16:56:55.830000000      2.0           42.0
# 4   143  2008-08-01 17:01:27.240000000      3.0           86.0
#
#    CommentCount_A  ClosedDate_A  QId  AId  accepted  Id_Q  ... ViewCount  \
# 0             2.0           NaN  126  127         1   126  ...      6357
# 1             2.0           NaN  126  128         0   126  ...      6357
# 2             0.0           NaN  126  139         0   126  ...      6357
# 3             0.0           NaN  126  142         0   126  ...      6357
# 4             0.0           NaN  126  143         0   126  ...      6357
#
#    OwnerUserId_Q  CommentCount_Q         ClosedDate_Q  FavoriteCount    Id  \
# 0           58.0               0  2012-05-08 18:11:27              2  35.0
# 1           58.0               0  2012-05-08 18:11:27              2  26.0
# 2           58.0               0  2012-05-08 18:11:27              2  72.0
# 3           58.0               0  2012-05-08 18:11:27              2  42.0
# 4           58.0               0  2012-05-08 18:11:27              2  86.0
#
#    Reputation   Views  UpVotes  DownVotes
# 0     11543.0  1060.0    436.0      208.0
# 1      8520.0  2843.0    564.0       67.0
# 2     18882.0  1118.0   1168.0       21.0
# 3     13820.0   754.0    359.0       45.0
# 4      3578.0   366.0   1641.0       59.0
#
# [5 rows x 22 columns]

# %%
len(merged_A_Q_U2)
# Out:
# 1510812

# %%
merged_A_Q_U2[merged_A_Q_U2['Id'].isnull()]
# Out:
#              Id_A                 CreationDate_A  Score_A  OwnerUserId_A  \
# 12          62045  2008-09-15 09:46:13.973000000      2.0            NaN
# 57           2216  2008-08-05 12:50:59.020000000      1.0            NaN
# 59           9086  2008-08-12 17:58:25.630000000      0.0            NaN
# 64           2977  2008-08-06 00:16:25.020000000      5.0            NaN
# 98          45518  2008-09-05 10:34:05.583000000      1.0            NaN
# ...           ...                            ...      ...            ...
# 1502341  28739905  2015-02-26 10:26:40.583000000      0.0            NaN
# 1503357  28764091  2015-02-27 11:29:49.967000000      1.0            NaN
# 1504171  28781215  2015-02-28 11:32:52.213000000      1.0            NaN
# 1504180  28781360  2015-02-28 11:48:42.503000000     -1.0            NaN
# 1510308  28913259  2015-03-07 09:16:44.257000000      0.0            NaN
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 12                  0.0           NaN       126     62045         0       126
# 57                  0.0           NaN      2092      2216         0      2092
# 59                  0.0           NaN      2092      9086         0      2092
# 64                  0.0           NaN      2968      2977         0      2968
# 98                  1.0           NaN      3881     45518         0      3881
# ...                 ...           ...       ...       ...       ...       ...
# 1502341             0.0           NaN  28739520  28739905         0  28739520
# 1503357             0.0           NaN  28763403  28764091         0  28763403
# 1504171             0.0           NaN  28781162  28781215         0  28781162
# 1504180             2.0           NaN  28781218  28781360         0  28781218
# 1510308             0.0           NaN  28913237  28913259         0  28913237
#
#          ... ViewCount  OwnerUserId_Q  CommentCount_Q         ClosedDate_Q  \
# 12       ...      6357           58.0               0  2012-05-08 18:11:27
# 57       ...      1411            NaN               0                  NaN
# 59       ...      1411            NaN               0                  NaN
# 64       ...     42848          362.0               1  2014-05-13 17:04:49
# 98       ...     61344          122.0               3                  NaN
# ...      ...       ...            ...             ...                  ...
# 1502341  ...        22      3693338.0               3                  NaN
# 1503357  ...        41      2816909.0               7                  NaN
# 1504171  ...        39      3787809.0               2                  NaN
# 1504180  ...        29      1941853.0               5                  NaN
# 1510308  ...        27      4643723.0               2                  NaN
#
#          FavoriteCount  Id  Reputation  Views  UpVotes  DownVotes
# 12                   2 NaN         NaN    NaN      NaN        NaN
# 57                   0 NaN         NaN    NaN      NaN        NaN
# 59                   0 NaN         NaN    NaN      NaN        NaN
# 64                   3 NaN         NaN    NaN      NaN        NaN
# 98                  72 NaN         NaN    NaN      NaN        NaN
# ...                ...  ..         ...    ...      ...        ...
# 1502341              0 NaN         NaN    NaN      NaN        NaN
# 1503357              0 NaN         NaN    NaN      NaN        NaN
# 1504171              0 NaN         NaN    NaN      NaN        NaN
# 1504180              0 NaN         NaN    NaN      NaN        NaN
# 1510308              0 NaN         NaN    NaN      NaN        NaN
#
# [7325 rows x 22 columns]

# %%
badge_count = user_badge.groupby('UserId').size().reset_index(name='badgeCount')
badge_count
# Out:
#           UserId  badgeCount
# 0              1         298
# 1              2          72
# 2              3         109
# 3              4         165
# 4              5         284
# ...          ...         ...
# 2094762  4645953           1
# 2094763  4645962           1
# 2094764  4645964           1
# 2094765  4645973           1
# 2094766  4645977           1
#
# [2094767 rows x 2 columns]

# %%
merged_A_Q_U_B = pd.merge(merged_A_Q_U, badge_count, left_on='Id', right_on='UserId', how='inner')
merged_A_Q_U_B.head()
# Out:
#     Id_A                 CreationDate_A  Score_A  OwnerUserId_A  \
# 0    127  2008-08-01 16:13:47.600000000     37.0           35.0
# 1   3886  2008-08-06 19:29:24.427000000    133.0           35.0
# 2  11567  2008-08-14 19:26:35.570000000      1.0           35.0
# 3  19904  2008-08-21 13:37:58.600000000    135.0           35.0
# 4  26311  2008-08-25 16:01:58.660000000     20.0           35.0
#
#    CommentCount_A  ClosedDate_A    QId    AId  accepted   Id_Q  ...  \
# 0             2.0           NaN    126    127         1    126  ...
# 1             1.0           NaN   3881   3886         1   3881  ...
# 2             0.0           NaN  11561  11567         0  11561  ...
# 3             0.0           NaN  19893  19904         1  19893  ...
# 4             7.0           NaN  26305  26311         0  26305  ...
#
#   CommentCount_Q         ClosedDate_Q  FavoriteCount  Id  Reputation Views  \
# 0              0  2012-05-08 18:11:27              2  35       11543  1060
# 1              3                  NaN             72  35       11543  1060
# 2              0                  NaN              4  35       11543  1060
# 3              1                  NaN             18  35       11543  1060
# 4              1                  NaN             43  35       11543  1060
#
#    UpVotes  DownVotes  UserId  badgeCount
# 0      436        208      35         113
# 1      436        208      35         113
# 2      436        208      35         113
# 3      436        208      35         113
# 4      436        208      35         113
#
# [5 rows x 24 columns]

# %%
len(merged_A_Q_U_B)
# Out:
# 1488203

# %%
merged_A_Q_U_B['ClosedDate_Q']
# Out:
# 0          2012-05-08 18:11:27
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#                   ...
# 1488198                    NaN
# 1488199                    NaN
# 1488200                    NaN
# 1488201                    NaN
# 1488202                    NaN
# Name: ClosedDate_Q, Length: 1488203, dtype: object

# %%
merged_A_Q_U_B['Closed_Q'] = merged_A_Q_U_B['ClosedDate_Q'].notnull().astype(int)

# %%
merged_A_Q_U_B['Closed_Q']
# Out:
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1488198    0
# 1488199    0
# 1488200    0
# 1488201    0
# 1488202    0
# Name: Closed_Q, Length: 1488203, dtype: int64

# %%
merged_A_Q_U_B.columns
# Out:
# Index(['Id_A', 'CreationDate_A', 'Score_A', 'OwnerUserId_A', 'CommentCount_A',
#        'ClosedDate_A', 'QId', 'AId', 'accepted', 'Id_Q', 'CreationDate_Q',
#        'Score_Q', 'ViewCount', 'OwnerUserId_Q', 'CommentCount_Q',
#        'ClosedDate_Q', 'FavoriteCount', 'Id', 'Reputation', 'Views', 'UpVotes',
#        'DownVotes', 'UserId', 'badgeCount', 'Closed_Q'],
#       dtype='object')

# %%
merged_A_Q_U_B['CreationDate_A'] = pd.to_datetime(merged_A_Q_U_B['CreationDate_A'])
merged_A_Q_U_B['CreationDate_Q'] = pd.to_datetime(merged_A_Q_U_B['CreationDate_Q'])
merged_A_Q_U_B['timeDiffrence(Hours)'] = (merged_A_Q_U_B['CreationDate_A'] - merged_A_Q_U_B['CreationDate_Q']).dt.total_seconds() / 60 / 60 #based on hours
merged_A_Q_U_B['timeDiffrence(Hours)']
# Out:
# 0          0.054889
# 1          0.048174
# 2          0.044603
# 3          0.036556
# 4          0.031850
#              ...
# 1488198    0.166627
# 1488199    0.549986
# 1488200    1.734582
# 1488201    0.309215
# 1488202    0.069180
# Name: timeDiffrence(Hours), Length: 1488203, dtype: float64

# %%
merged_A_Q_U_B[merged_A_Q_U_B['timeDiffrence(Hours)']==0]
# Out:
#              Id_A      CreationDate_A  Score_A  OwnerUserId_A  CommentCount_A  \
# 205237   14554596 2013-01-28 02:23:27      5.0         8123.0             1.0
# 220013   20799711 2013-12-27 11:14:49      9.0       418556.0             5.0
# 1097537  11641986 2012-07-25 02:46:34      5.0      1339751.0             4.0
# 1109418  12644018 2012-09-28 16:38:24      1.0       902217.0             0.0
# 1142057  12683022 2012-10-02 00:33:43      4.0       650558.0             0.0
# 1322645  19215085 2013-10-06 23:18:43      0.0      1478808.0             0.0
#
#          ClosedDate_A       QId       AId  accepted      Id_Q  ...  \
# 205237            NaN  14554595  14554596         1  14554595  ...
# 220013            NaN  20799710  20799711         1  20799710  ...
# 1097537           NaN  11641985  11641986         0  11641985  ...
# 1109418           NaN  12644017  12644018         1  12644017  ...
# 1142057           NaN  12683020  12683022         1  12683020  ...
# 1322645           NaN  19215084  19215085         1  19215084  ...
#
#         FavoriteCount       Id  Reputation  Views  UpVotes DownVotes   UserId  \
# 205237              1     8123       35143   2161     1937       192     8123
# 220013              0   418556      117299  25726    12690      4280   418556
# 1097537             6  1339751         370     46       15         0  1339751
# 1109418             0   902217        1281    665     2082        39   902217
# 1142057             0   650558        1665    190      389         8   650558
# 1322645             1  1478808         372     50       39         0  1478808
#
#          badgeCount  Closed_Q  timeDiffrence(Hours)
# 205237          237         0                   0.0
# 220013          295         0                   0.0
# 1097537          20         0                   0.0
# 1109418          65         0                   0.0
# 1142057          81         0                   0.0
# 1322645          17         0                   0.0
#
# [6 rows x 26 columns]

# %%
merged_A_Q_U_B[merged_A_Q_U_B['timeDiffrence(Hours)']<0]
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 55          58612 2008-09-12 10:19:01.440      2.0          518.0
# 5322        57134 2008-09-11 17:26:52.853      7.0         4926.0
# 7007     22253141 2014-03-07 14:42:57.793      0.0      2736496.0
# 7134     23259195 2014-04-24 03:18:32.743      0.0      2736496.0
# 7137     24516963 2014-07-01 18:24:20.787      1.0      2736496.0
# ...           ...                     ...      ...            ...
# 1479990  28115735 2015-01-23 17:48:22.877      0.0       246568.0
# 1480059  28121620 2015-01-24 02:16:17.947      0.0      1696177.0
# 1480934  28204737 2015-01-28 23:59:56.603      0.0        69173.0
# 1481100  28572784 2015-02-17 22:57:04.803      0.0       373418.0
# 1484132  28490027 2015-02-12 23:42:19.597      0.0       105703.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 55                  0.0           NaN    462923     58612         0    462923
# 5322                0.0           NaN    462923     57134         0    462923
# 7007                4.0           NaN  22253140  22253141         0  22253140
# 7134               13.0           NaN  23259194  23259195         0  23259194
# 7137                0.0           NaN  24516962  24516963         0  24516962
# ...                 ...           ...       ...       ...       ...       ...
# 1479990             0.0           NaN  28115734  28115735         0  28115734
# 1480059             0.0           NaN  28121619  28121620         0  28121619
# 1480934             0.0           NaN  28204736  28204737         0  28204736
# 1481100             6.0           NaN  28572783  28572784         1  28572783
# 1484132             0.0           NaN  28490026  28490027         0  28490026
#
#          ... FavoriteCount       Id  Reputation  Views  UpVotes DownVotes  \
# 55       ...            26      518        2418    357      113         4
# 5322     ...            26     4926       39308   5729      981       176
# 7007     ...             0  2736496        7775    856      724       598
# 7134     ...             0  2736496        7775    856      724       598
# 7137     ...             0  2736496        7775    856      724       598
# ...      ...           ...      ...         ...    ...      ...       ...
# 1479990  ...             0   246568       10067    992      724         5
# 1480059  ...             0  1696177          22     13        0         0
# 1480934  ...             0    69173        1225    176     3723        18
# 1481100  ...             0   373418         970    150      121        10
# 1484132  ...             0   105703         416     38        2         0
#
#           UserId  badgeCount  Closed_Q  timeDiffrence(Hours)
# 55           518          56         1          -3129.968767
# 5322        4926         197         1          -3146.837819
# 7007     2736496          72         0             -0.000058
# 7134     2736496          72         0             -0.000071
# 7137     2736496          72         0             -0.000059
# ...          ...         ...       ...                   ...
# 1479990   246568         315         0             -0.000034
# 1480059  1696177           6         0             -0.000015
# 1480934    69173          33         0             -0.000110
# 1481100   373418          19         0             -0.000055
# 1484132   105703          13         0             -0.000112
#
# [587 rows x 26 columns]

# %%
len(merged_A_Q_U_B)
# Out:
# 1488203

# %%
merged_A_Q_U_B2 = merged_A_Q_U_B[merged_A_Q_U_B['timeDiffrence(Hours)']>0]

# %%
len(merged_A_Q_U_B2)
# Out:
# 1487610

# %%
merged_A_Q_U_B2.columns
# Out:
# Index(['Id_A', 'CreationDate_A', 'Score_A', 'OwnerUserId_A', 'CommentCount_A',
#        'ClosedDate_A', 'QId', 'AId', 'accepted', 'Id_Q', 'CreationDate_Q',
#        'Score_Q', 'ViewCount', 'OwnerUserId_Q', 'CommentCount_Q',
#        'ClosedDate_Q', 'FavoriteCount', 'Id', 'Reputation', 'Views', 'UpVotes',
#        'DownVotes', 'UserId', 'badgeCount', 'Closed_Q',
#        'timeDiffrence(Hours)'],
#       dtype='object')

# %%
df_answers = merged_A_Q_U_B2.groupby('OwnerUserId_A').size().reset_index(name='#answers_A')
df_answers
# Out:
#         OwnerUserId_A  #answers_A
# 0                 1.0           2
# 1                 3.0           1
# 2                 9.0           1
# 3                13.0         441
# 4                17.0           9
# ...               ...         ...
# 192146      4644935.0           3
# 192147      4645046.0           1
# 192148      4645110.0           4
# 192149      4645296.0           1
# 192150      4645692.0           1
#
# [192151 rows x 2 columns]

# %%
sum(df_answers['#answers_A'].isnull())
# Out:
# 0

# %%
df_answers_mean = merged_A_Q_U_B2.groupby('OwnerUserId_A')['accepted'].mean().reset_index(name='accepted_ratio_A')
df_answers_mean
# Out:
#         OwnerUserId_A  accepted_ratio_A
# 0                 1.0          0.000000
# 1                 3.0          0.000000
# 2                 9.0          0.000000
# 3                13.0          0.444444
# 4                17.0          0.111111
# ...               ...               ...
# 192146      4644935.0          0.333333
# 192147      4645046.0          0.000000
# 192148      4645110.0          0.250000
# 192149      4645296.0          0.000000
# 192150      4645692.0          0.000000
#
# [192151 rows x 2 columns]

# %%
merged_df = pd.merge(df_answers, df_answers_mean,  left_on='OwnerUserId_A', right_on='OwnerUserId_A', how='left')
merged_df
# Out:
#         OwnerUserId_A  #answers_A  accepted_ratio_A
# 0                 1.0           2          0.000000
# 1                 3.0           1          0.000000
# 2                 9.0           1          0.000000
# 3                13.0         441          0.444444
# 4                17.0           9          0.111111
# ...               ...         ...               ...
# 192146      4644935.0           3          0.333333
# 192147      4645046.0           1          0.000000
# 192148      4645110.0           4          0.250000
# 192149      4645296.0           1          0.000000
# 192150      4645692.0           1          0.000000
#
# [192151 rows x 3 columns]

# %%
merged_A_Q_U_B2.columns
# Out:
# Index(['Id_A', 'CreationDate_A', 'Score_A', 'OwnerUserId_A', 'CommentCount_A',
#        'ClosedDate_A', 'QId', 'AId', 'accepted', 'Id_Q', 'CreationDate_Q',
#        'Score_Q', 'ViewCount', 'OwnerUserId_Q', 'CommentCount_Q',
#        'ClosedDate_Q', 'FavoriteCount', 'Id', 'Reputation', 'Views', 'UpVotes',
#        'DownVotes', 'UserId', 'badgeCount', 'Closed_Q',
#        'timeDiffrence(Hours)'],
#       dtype='object')

# %%
len(merged_A_Q_U_B2)
# Out:
# 1487610

# %%
merged_A_Q_U_B2_R = pd.merge(merged_A_Q_U_B2, merged_df,  left_on='OwnerUserId_A', right_on='OwnerUserId_A', how='inner')
merged_A_Q_U_B2_R
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1            3886 2008-08-06 19:29:24.427    133.0           35.0
# 2           11567 2008-08-14 19:26:35.570      1.0           35.0
# 3           19904 2008-08-21 13:37:58.600    135.0           35.0
# 4           26311 2008-08-25 16:01:58.660     20.0           35.0
# ...           ...                     ...      ...            ...
# 1487605  28922535 2015-03-08 02:48:19.857      0.0      4645692.0
# 1487606  28922813 2015-03-08 03:40:11.950      0.0      3313892.0
# 1487607  28922747 2015-03-08 03:24:05.497      0.0      4643110.0
# 1487608  28922923 2015-03-08 04:00:36.173      0.0      4643110.0
# 1487609  28922833 2015-03-08 03:46:12.047      1.0      3773229.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   1.0           NaN      3881      3886         1      3881
# 2                   0.0           NaN     11561     11567         0     11561
# 3                   0.0           NaN     19893     19904         1     19893
# 4                   7.0           NaN     26305     26311         0     26305
# ...                 ...           ...       ...       ...       ...       ...
# 1487605             2.0           NaN  28922468  28922535         0  28922468
# 1487606             0.0           NaN  28922649  28922813         0  28922649
# 1487607             2.0           NaN  28922175  28922747         0  28922175
# 1487608             0.0           NaN  28922819  28922923         0  28922819
# 1487609             1.0           NaN  28922819  28922833         0  28922819
#
#          ... Reputation  Views  UpVotes  DownVotes   UserId badgeCount  \
# 0        ...      11543   1060      436        208       35        113
# 1        ...      11543   1060      436        208       35        113
# 2        ...      11543   1060      436        208       35        113
# 3        ...      11543   1060      436        208       35        113
# 4        ...      11543   1060      436        208       35        113
# ...      ...        ...    ...      ...        ...      ...        ...
# 1487605  ...          1      1        0          0  4645692          3
# 1487606  ...          1      0        0          0  3313892          1
# 1487607  ...          1      0        0          0  4643110          2
# 1487608  ...          1      0        0          0  4643110          2
# 1487609  ...         69     12        7          0  3773229          4
#
#          Closed_Q  timeDiffrence(Hours)  #answers_A  accepted_ratio_A
# 0               1              0.054889           5               0.6
# 1               0              0.048174           5               0.6
# 2               0              0.044603           5               0.6
# 3               0              0.036556           5               0.6
# 4               0              0.031850           5               0.6
# ...           ...                   ...         ...               ...
# 1487605         0              0.166627           1               0.0
# 1487606         0              0.549986           1               0.0
# 1487607         0              1.734582           2               0.0
# 1487608         0              0.309215           2               0.0
# 1487609         0              0.069180           1               0.0
#
# [1487610 rows x 28 columns]

# %%
# Function to calculate the new column to exclude the current smaple from accepted_ratio_A

def calculate_value(row):
  if  row['#answers_A'] < 2 :
    return np.nan
  else :
    if row['accepted'] == 1:
        return ((row['accepted_ratio_A'] * row['#answers_A']) - 1) / (row['#answers_A'] - 1)
    else:
        return (row['accepted_ratio_A'] * row['#answers_A']) / (row['#answers_A'] - 1)

# Apply the function to create the new column 'new_column'
merged_A_Q_U_B2_R['corrected_accepted_ratio_A'] = merged_A_Q_U_B2_R.apply(lambda row: calculate_value(row), axis=1)

# %%
merged_A_Q_U_B2_R
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1            3886 2008-08-06 19:29:24.427    133.0           35.0
# 2           11567 2008-08-14 19:26:35.570      1.0           35.0
# 3           19904 2008-08-21 13:37:58.600    135.0           35.0
# 4           26311 2008-08-25 16:01:58.660     20.0           35.0
# ...           ...                     ...      ...            ...
# 1487605  28922535 2015-03-08 02:48:19.857      0.0      4645692.0
# 1487606  28922813 2015-03-08 03:40:11.950      0.0      3313892.0
# 1487607  28922747 2015-03-08 03:24:05.497      0.0      4643110.0
# 1487608  28922923 2015-03-08 04:00:36.173      0.0      4643110.0
# 1487609  28922833 2015-03-08 03:46:12.047      1.0      3773229.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   1.0           NaN      3881      3886         1      3881
# 2                   0.0           NaN     11561     11567         0     11561
# 3                   0.0           NaN     19893     19904         1     19893
# 4                   7.0           NaN     26305     26311         0     26305
# ...                 ...           ...       ...       ...       ...       ...
# 1487605             2.0           NaN  28922468  28922535         0  28922468
# 1487606             0.0           NaN  28922649  28922813         0  28922649
# 1487607             2.0           NaN  28922175  28922747         0  28922175
# 1487608             0.0           NaN  28922819  28922923         0  28922819
# 1487609             1.0           NaN  28922819  28922833         0  28922819
#
#          ... Views  UpVotes  DownVotes   UserId  badgeCount Closed_Q  \
# 0        ...  1060      436        208       35         113        1
# 1        ...  1060      436        208       35         113        0
# 2        ...  1060      436        208       35         113        0
# 3        ...  1060      436        208       35         113        0
# 4        ...  1060      436        208       35         113        0
# ...      ...   ...      ...        ...      ...         ...      ...
# 1487605  ...     1        0          0  4645692           3        0
# 1487606  ...     0        0          0  3313892           1        0
# 1487607  ...     0        0          0  4643110           2        0
# 1487608  ...     0        0          0  4643110           2        0
# 1487609  ...    12        7          0  3773229           4        0
#
#          timeDiffrence(Hours)  #answers_A  accepted_ratio_A  \
# 0                    0.054889           5               0.6
# 1                    0.048174           5               0.6
# 2                    0.044603           5               0.6
# 3                    0.036556           5               0.6
# 4                    0.031850           5               0.6
# ...                       ...         ...               ...
# 1487605              0.166627           1               0.0
# 1487606              0.549986           1               0.0
# 1487607              1.734582           2               0.0
# 1487608              0.309215           2               0.0
# 1487609              0.069180           1               0.0
#
#          corrected_accepted_ratio_A
# 0                              0.50
# 1                              0.50
# 2                              0.75
# 3                              0.50
# 4                              0.75
# ...                             ...
# 1487605                         NaN
# 1487606                         NaN
# 1487607                        0.00
# 1487608                        0.00
# 1487609                         NaN
#
# [1487610 rows x 29 columns]

# %%
mean_value  = merged_A_Q_U_B2_R['corrected_accepted_ratio_A'].mean()
# Out:
# 0.3092488049037868

# %%
# Fill null values in 'corrected_accepted_ratio_A' with mean

mean_value  = merged_A_Q_U_B2_R['corrected_accepted_ratio_A'].mean()
merged_A_Q_U_B2_R['corrected_accepted_ratio_A'].fillna(round(mean_value, 2), inplace=True)
merged_A_Q_U_B2_R
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1            3886 2008-08-06 19:29:24.427    133.0           35.0
# 2           11567 2008-08-14 19:26:35.570      1.0           35.0
# 3           19904 2008-08-21 13:37:58.600    135.0           35.0
# 4           26311 2008-08-25 16:01:58.660     20.0           35.0
# ...           ...                     ...      ...            ...
# 1487605  28922535 2015-03-08 02:48:19.857      0.0      4645692.0
# 1487606  28922813 2015-03-08 03:40:11.950      0.0      3313892.0
# 1487607  28922747 2015-03-08 03:24:05.497      0.0      4643110.0
# 1487608  28922923 2015-03-08 04:00:36.173      0.0      4643110.0
# 1487609  28922833 2015-03-08 03:46:12.047      1.0      3773229.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   1.0           NaN      3881      3886         1      3881
# 2                   0.0           NaN     11561     11567         0     11561
# 3                   0.0           NaN     19893     19904         1     19893
# 4                   7.0           NaN     26305     26311         0     26305
# ...                 ...           ...       ...       ...       ...       ...
# 1487605             2.0           NaN  28922468  28922535         0  28922468
# 1487606             0.0           NaN  28922649  28922813         0  28922649
# 1487607             2.0           NaN  28922175  28922747         0  28922175
# 1487608             0.0           NaN  28922819  28922923         0  28922819
# 1487609             1.0           NaN  28922819  28922833         0  28922819
#
#          ... Views  UpVotes  DownVotes   UserId  badgeCount Closed_Q  \
# 0        ...  1060      436        208       35         113        1
# 1        ...  1060      436        208       35         113        0
# 2        ...  1060      436        208       35         113        0
# 3        ...  1060      436        208       35         113        0
# 4        ...  1060      436        208       35         113        0
# ...      ...   ...      ...        ...      ...         ...      ...
# 1487605  ...     1        0          0  4645692           3        0
# 1487606  ...     0        0          0  3313892           1        0
# 1487607  ...     0        0          0  4643110           2        0
# 1487608  ...     0        0          0  4643110           2        0
# 1487609  ...    12        7          0  3773229           4        0
#
#          timeDiffrence(Hours)  #answers_A  accepted_ratio_A  \
# 0                    0.054889           5               0.6
# 1                    0.048174           5               0.6
# 2                    0.044603           5               0.6
# 3                    0.036556           5               0.6
# 4                    0.031850           5               0.6
# ...                       ...         ...               ...
# 1487605              0.166627           1               0.0
# 1487606              0.549986           1               0.0
# 1487607              1.734582           2               0.0
# 1487608              0.309215           2               0.0
# 1487609              0.069180           1               0.0
#
#          corrected_accepted_ratio_A
# 0                              0.50
# 1                              0.50
# 2                              0.75
# 3                              0.50
# 4                              0.75
# ...                             ...
# 1487605                        0.31
# 1487606                        0.31
# 1487607                        0.00
# 1487608                        0.00
# 1487609                        0.31
#
# [1487610 rows x 29 columns]

# %%
df = merged_A_Q_U_B2_R.groupby('QId').size().reset_index(name='#answers_Q')
df
# Out:
#              QId  #answers_Q
# 0            123          17
# 1            126          18
# 2            382           1
# 3            564          15
# 4           2092           3
# ...          ...         ...
# 717670  28922732           1
# 717671  28922734           1
# 717672  28922819           5
# 717673  28922872           2
# 717674  28922876           1
#
# [717675 rows x 2 columns]

# %%
merged_A_Q_U_B2_R2 = pd.merge(merged_A_Q_U_B2_R, df,  left_on='QId', right_on='QId', how='left')
merged_A_Q_U_B2_R2
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1            3886 2008-08-06 19:29:24.427    133.0           35.0
# 2           11567 2008-08-14 19:26:35.570      1.0           35.0
# 3           19904 2008-08-21 13:37:58.600    135.0           35.0
# 4           26311 2008-08-25 16:01:58.660     20.0           35.0
# ...           ...                     ...      ...            ...
# 1487605  28922535 2015-03-08 02:48:19.857      0.0      4645692.0
# 1487606  28922813 2015-03-08 03:40:11.950      0.0      3313892.0
# 1487607  28922747 2015-03-08 03:24:05.497      0.0      4643110.0
# 1487608  28922923 2015-03-08 04:00:36.173      0.0      4643110.0
# 1487609  28922833 2015-03-08 03:46:12.047      1.0      3773229.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   1.0           NaN      3881      3886         1      3881
# 2                   0.0           NaN     11561     11567         0     11561
# 3                   0.0           NaN     19893     19904         1     19893
# 4                   7.0           NaN     26305     26311         0     26305
# ...                 ...           ...       ...       ...       ...       ...
# 1487605             2.0           NaN  28922468  28922535         0  28922468
# 1487606             0.0           NaN  28922649  28922813         0  28922649
# 1487607             2.0           NaN  28922175  28922747         0  28922175
# 1487608             0.0           NaN  28922819  28922923         0  28922819
# 1487609             1.0           NaN  28922819  28922833         0  28922819
#
#          ... UpVotes  DownVotes   UserId  badgeCount  Closed_Q  \
# 0        ...     436        208       35         113         1
# 1        ...     436        208       35         113         0
# 2        ...     436        208       35         113         0
# 3        ...     436        208       35         113         0
# 4        ...     436        208       35         113         0
# ...      ...     ...        ...      ...         ...       ...
# 1487605  ...       0          0  4645692           3         0
# 1487606  ...       0          0  3313892           1         0
# 1487607  ...       0          0  4643110           2         0
# 1487608  ...       0          0  4643110           2         0
# 1487609  ...       7          0  3773229           4         0
#
#         timeDiffrence(Hours)  #answers_A  accepted_ratio_A  \
# 0                   0.054889           5               0.6
# 1                   0.048174           5               0.6
# 2                   0.044603           5               0.6
# 3                   0.036556           5               0.6
# 4                   0.031850           5               0.6
# ...                      ...         ...               ...
# 1487605             0.166627           1               0.0
# 1487606             0.549986           1               0.0
# 1487607             1.734582           2               0.0
# 1487608             0.309215           2               0.0
# 1487609             0.069180           1               0.0
#
#          corrected_accepted_ratio_A  #answers_Q
# 0                              0.50          18
# 1                              0.50          21
# 2                              0.75           4
# 3                              0.50          13
# 4                              0.75           6
# ...                             ...         ...
# 1487605                        0.31           2
# 1487606                        0.31           2
# 1487607                        0.00           1
# 1487608                        0.00           5
# 1487609                        0.31           5
#
# [1487610 rows x 30 columns]

# %%
# Grouping the DataFrame by 'QId'
grouped = merged_A_Q_U_B2_R.groupby('QId')

result_dict = {}
# Iterating through each group
for qid, group in grouped:
    for index, row in group.iterrows():
      current_id = row['Id_A']
      current_time_diff = row['timeDiffrence(Hours)']

      # Counting the number of other Id_A with less time difference for the current Id_A
      count = sum(group['timeDiffrence(Hours)'] < current_time_diff)

      # Storing the count for the current Id_A
      result_dict[current_id] = count

# %%
len(result_dict)
# Out:
# 1487610

# %%
result_df = pd.DataFrame(list(result_dict.items()), columns=['Id_A', 'Less_Time_Diff_Count'])
result_df
# Out:
#              Id_A  Less_Time_Diff_Count
# 0             183                     1
# 1             133                     0
# 2             190                     2
# 3             540                     3
# 4             939                     4
# ...           ...                   ...
# 1487605  28922923                     4
# 1487606  28922833                     0
# 1487607  28922940                     1
# 1487608  28922900                     0
# 1487609  28922943                     0
#
# [1487610 rows x 2 columns]

# %%
merged_A_Q_U_B2_R2.columns
# Out:
# Index(['Id_A', 'CreationDate_A', 'Score_A', 'OwnerUserId_A', 'CommentCount_A',
#        'ClosedDate_A', 'QId', 'AId', 'accepted', 'Id_Q', 'CreationDate_Q',
#        'Score_Q', 'ViewCount', 'OwnerUserId_Q', 'CommentCount_Q',
#        'ClosedDate_Q', 'FavoriteCount', 'Id', 'Reputation', 'Views', 'UpVotes',
#        'DownVotes', 'UserId', 'badgeCount', 'Closed_Q', 'timeDiffrence(Hours)',
#        '#answers_A', 'accepted_ratio_A', 'corrected_accepted_ratio_A',
#        '#answers_Q'],
#       dtype='object')

# %%
merged_A_Q_U_B2_R3 = pd.merge(merged_A_Q_U_B2_R2, result_df,  left_on='Id_A', right_on='Id_A', how='inner')
merged_A_Q_U_B2_R3
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1            3886 2008-08-06 19:29:24.427    133.0           35.0
# 2           11567 2008-08-14 19:26:35.570      1.0           35.0
# 3           19904 2008-08-21 13:37:58.600    135.0           35.0
# 4           26311 2008-08-25 16:01:58.660     20.0           35.0
# ...           ...                     ...      ...            ...
# 1487605  28922535 2015-03-08 02:48:19.857      0.0      4645692.0
# 1487606  28922813 2015-03-08 03:40:11.950      0.0      3313892.0
# 1487607  28922747 2015-03-08 03:24:05.497      0.0      4643110.0
# 1487608  28922923 2015-03-08 04:00:36.173      0.0      4643110.0
# 1487609  28922833 2015-03-08 03:46:12.047      1.0      3773229.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   1.0           NaN      3881      3886         1      3881
# 2                   0.0           NaN     11561     11567         0     11561
# 3                   0.0           NaN     19893     19904         1     19893
# 4                   7.0           NaN     26305     26311         0     26305
# ...                 ...           ...       ...       ...       ...       ...
# 1487605             2.0           NaN  28922468  28922535         0  28922468
# 1487606             0.0           NaN  28922649  28922813         0  28922649
# 1487607             2.0           NaN  28922175  28922747         0  28922175
# 1487608             0.0           NaN  28922819  28922923         0  28922819
# 1487609             1.0           NaN  28922819  28922833         0  28922819
#
#          ... DownVotes   UserId  badgeCount  Closed_Q  timeDiffrence(Hours)  \
# 0        ...       208       35         113         1              0.054889
# 1        ...       208       35         113         0              0.048174
# 2        ...       208       35         113         0              0.044603
# 3        ...       208       35         113         0              0.036556
# 4        ...       208       35         113         0              0.031850
# ...      ...       ...      ...         ...       ...                   ...
# 1487605  ...         0  4645692           3         0              0.166627
# 1487606  ...         0  3313892           1         0              0.549986
# 1487607  ...         0  4643110           2         0              1.734582
# 1487608  ...         0  4643110           2         0              0.309215
# 1487609  ...         0  3773229           4         0              0.069180
#
#         #answers_A  accepted_ratio_A  corrected_accepted_ratio_A  #answers_Q  \
# 0                5               0.6                        0.50          18
# 1                5               0.6                        0.50          21
# 2                5               0.6                        0.75           4
# 3                5               0.6                        0.50          13
# 4                5               0.6                        0.75           6
# ...            ...               ...                         ...         ...
# 1487605          1               0.0                        0.31           2
# 1487606          1               0.0                        0.31           2
# 1487607          2               0.0                        0.00           1
# 1487608          2               0.0                        0.00           5
# 1487609          1               0.0                        0.31           5
#
#          Less_Time_Diff_Count
# 0                           0
# 1                           0
# 2                           0
# 3                           2
# 4                           0
# ...                       ...
# 1487605                     0
# 1487606                     1
# 1487607                     0
# 1487608                     4
# 1487609                     0
#
# [1487610 rows x 31 columns]

# %%
df_Q = merged_A_Q_U_B2_R3.groupby('OwnerUserId_Q').size().reset_index(name='#answers_Q_U')
df_Q
# Out:
#         OwnerUserId_Q  #answers_Q_U
# 0                13.0             4
# 1                22.0            17
# 2                25.0            15
# 3                27.0             7
# 4                40.0             3
# ...               ...           ...
# 243101      4645615.0             1
# 243102      4645687.0             1
# 243103      4645700.0             2
# 243104      4645731.0             1
# 243105      4645748.0             2
#
# [243106 rows x 2 columns]

# %%
df_Q_mean = merged_A_Q_U_B2_R3.groupby('OwnerUserId_Q')['accepted'].mean().reset_index(name='accepted_ratio_Q')
df_Q_mean
# Out:
#         OwnerUserId_Q  accepted_ratio_Q
# 0                13.0          0.500000
# 1                22.0          0.294118
# 2                25.0          0.066667
# 3                27.0          0.142857
# 4                40.0          0.333333
# ...               ...               ...
# 243101      4645615.0          0.000000
# 243102      4645687.0          0.000000
# 243103      4645700.0          0.000000
# 243104      4645731.0          0.000000
# 243105      4645748.0          0.000000
#
# [243106 rows x 2 columns]

# %%
merged_df = pd.merge(df_Q, df_Q_mean,  left_on='OwnerUserId_Q', right_on='OwnerUserId_Q', how='left')
merged_df
# Out:
#         OwnerUserId_Q  #answers_Q_U  accepted_ratio_Q
# 0                13.0             4          0.500000
# 1                22.0            17          0.294118
# 2                25.0            15          0.066667
# 3                27.0             7          0.142857
# 4                40.0             3          0.333333
# ...               ...           ...               ...
# 243101      4645615.0             1          0.000000
# 243102      4645687.0             1          0.000000
# 243103      4645700.0             2          0.000000
# 243104      4645731.0             1          0.000000
# 243105      4645748.0             2          0.000000
#
# [243106 rows x 3 columns]

# %%
merged_A_Q_U_B2_R4 = pd.merge(merged_A_Q_U_B2_R3, merged_df,  left_on='OwnerUserId_Q', right_on='OwnerUserId_Q', how='inner')
merged_A_Q_U_B2_R4
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1             128 2008-08-01 16:19:04.283      7.0           26.0
# 2             139 2008-08-01 16:43:30.880      5.0           72.0
# 3             142 2008-08-01 16:56:55.830      2.0           42.0
# 4             143 2008-08-01 17:01:27.240      3.0           86.0
# ...           ...                     ...      ...            ...
# 1464091  28918051 2015-03-07 17:51:24.177      2.0      4638142.0
# 1464092  28919123 2015-03-07 19:39:56.343      0.0      3718088.0
# 1464093  28920032 2015-03-07 21:10:08.197      1.0      2641836.0
# 1464094  28922084 2015-03-08 01:24:30.083      1.0      4645110.0
# 1464095  28921393 2015-03-07 23:39:59.863      0.0      4641498.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   2.0           NaN       126       128         0       126
# 2                   0.0           NaN       126       139         0       126
# 3                   0.0           NaN       126       142         0       126
# 4                   0.0           NaN       126       143         0       126
# ...                 ...           ...       ...       ...       ...       ...
# 1464091             4.0           NaN  28917880  28918051         1  28917880
# 1464092             0.0           NaN  28797939  28919123         0  28797939
# 1464093             0.0           NaN  27829303  28920032         0  27829303
# 1464094             1.0           NaN  28921975  28922084         1  28921975
# 1464095             0.0           NaN  28902509  28921393         0  28902509
#
#          ... badgeCount  Closed_Q  timeDiffrence(Hours)  #answers_A  \
# 0        ...        113         1              0.054889           5
# 1        ...        212         1              0.142856           4
# 2        ...        160         1              0.550244           3
# 3        ...         92         1              0.773842           2
# 4        ...         73         1              0.849233          26
# ...      ...        ...       ...                   ...         ...
# 1464091  ...          4         0              0.256716           1
# 1464092  ...          5         0            144.329540           1
# 1464093  ...          4         0           1415.272277           1
# 1464094  ...          3         0              0.270579           4
# 1464095  ...          2         0             31.761906           1
#
#          accepted_ratio_A corrected_accepted_ratio_A  #answers_Q  \
# 0                0.600000                       0.50          18
# 1                0.000000                       0.00          18
# 2                0.000000                       0.00          18
# 3                0.000000                       0.00          18
# 4                0.192308                       0.20          18
# ...                   ...                        ...         ...
# 1464091          1.000000                       0.31           1
# 1464092          0.000000                       0.31           1
# 1464093          0.000000                       0.31           1
# 1464094          0.250000                       0.00           1
# 1464095          0.000000                       0.31           1
#
#          Less_Time_Diff_Count  #answers_Q_U  accepted_ratio_Q
# 0                           0            40               0.2
# 1                           1            40               0.2
# 2                           2            40               0.2
# 3                           3            40               0.2
# 4                           4            40               0.2
# ...                       ...           ...               ...
# 1464091                     0             1               1.0
# 1464092                     0             1               0.0
# 1464093                     0             1               0.0
# 1464094                     0             1               1.0
# 1464095                     0             1               0.0
#
# [1464096 rows x 33 columns]

# %%
# Function to calculate the new column to exclude the current smaple from accepted_ratio_A

def calculate_value(row):
  if  row['#answers_Q_U'] < 2 :
    return np.nan
  else :
    if row['accepted'] == 1:
        return ((row['accepted_ratio_Q'] * row['#answers_Q_U']) - 1) / (row['#answers_Q_U'] - 1)
    else:
        return (row['accepted_ratio_Q'] * row['#answers_Q_U']) / (row['#answers_Q_U'] - 1)

# Apply the function to create the new column 'new_column'
merged_A_Q_U_B2_R4['corrected_accepted_ratio_Q'] = merged_A_Q_U_B2_R4.apply(lambda row: calculate_value(row), axis=1)

# %%
merged_A_Q_U_B2_R4
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1             128 2008-08-01 16:19:04.283      7.0           26.0
# 2             139 2008-08-01 16:43:30.880      5.0           72.0
# 3             142 2008-08-01 16:56:55.830      2.0           42.0
# 4             143 2008-08-01 17:01:27.240      3.0           86.0
# ...           ...                     ...      ...            ...
# 1464091  28918051 2015-03-07 17:51:24.177      2.0      4638142.0
# 1464092  28919123 2015-03-07 19:39:56.343      0.0      3718088.0
# 1464093  28920032 2015-03-07 21:10:08.197      1.0      2641836.0
# 1464094  28922084 2015-03-08 01:24:30.083      1.0      4645110.0
# 1464095  28921393 2015-03-07 23:39:59.863      0.0      4641498.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   2.0           NaN       126       128         0       126
# 2                   0.0           NaN       126       139         0       126
# 3                   0.0           NaN       126       142         0       126
# 4                   0.0           NaN       126       143         0       126
# ...                 ...           ...       ...       ...       ...       ...
# 1464091             4.0           NaN  28917880  28918051         1  28917880
# 1464092             0.0           NaN  28797939  28919123         0  28797939
# 1464093             0.0           NaN  27829303  28920032         0  27829303
# 1464094             1.0           NaN  28921975  28922084         1  28921975
# 1464095             0.0           NaN  28902509  28921393         0  28902509
#
#          ... Closed_Q  timeDiffrence(Hours)  #answers_A  accepted_ratio_A  \
# 0        ...        1              0.054889           5          0.600000
# 1        ...        1              0.142856           4          0.000000
# 2        ...        1              0.550244           3          0.000000
# 3        ...        1              0.773842           2          0.000000
# 4        ...        1              0.849233          26          0.192308
# ...      ...      ...                   ...         ...               ...
# 1464091  ...        0              0.256716           1          1.000000
# 1464092  ...        0            144.329540           1          0.000000
# 1464093  ...        0           1415.272277           1          0.000000
# 1464094  ...        0              0.270579           4          0.250000
# 1464095  ...        0             31.761906           1          0.000000
#
#          corrected_accepted_ratio_A #answers_Q  Less_Time_Diff_Count  \
# 0                              0.50         18                     0
# 1                              0.00         18                     1
# 2                              0.00         18                     2
# 3                              0.00         18                     3
# 4                              0.20         18                     4
# ...                             ...        ...                   ...
# 1464091                        0.31          1                     0
# 1464092                        0.31          1                     0
# 1464093                        0.31          1                     0
# 1464094                        0.00          1                     0
# 1464095                        0.31          1                     0
#
#          #answers_Q_U  accepted_ratio_Q  corrected_accepted_ratio_Q
# 0                  40               0.2                    0.179487
# 1                  40               0.2                    0.205128
# 2                  40               0.2                    0.205128
# 3                  40               0.2                    0.205128
# 4                  40               0.2                    0.205128
# ...               ...               ...                         ...
# 1464091             1               1.0                         NaN
# 1464092             1               0.0                         NaN
# 1464093             1               0.0                         NaN
# 1464094             1               1.0                         NaN
# 1464095             1               0.0                         NaN
#
# [1464096 rows x 34 columns]

# %%
mean_value  = merged_A_Q_U_B2_R4['corrected_accepted_ratio_Q'].mean()
mean_value
# Out:
# 0.2982647312744519

# %%
# Fill null values in 'corrected_accepted_ratio_A' with mean

mean_value  = merged_A_Q_U_B2_R4['corrected_accepted_ratio_Q'].mean()
merged_A_Q_U_B2_R4['corrected_accepted_ratio_Q'].fillna(round(mean_value, 2), inplace=True)
merged_A_Q_U_B2_R4
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1             128 2008-08-01 16:19:04.283      7.0           26.0
# 2             139 2008-08-01 16:43:30.880      5.0           72.0
# 3             142 2008-08-01 16:56:55.830      2.0           42.0
# 4             143 2008-08-01 17:01:27.240      3.0           86.0
# ...           ...                     ...      ...            ...
# 1464091  28918051 2015-03-07 17:51:24.177      2.0      4638142.0
# 1464092  28919123 2015-03-07 19:39:56.343      0.0      3718088.0
# 1464093  28920032 2015-03-07 21:10:08.197      1.0      2641836.0
# 1464094  28922084 2015-03-08 01:24:30.083      1.0      4645110.0
# 1464095  28921393 2015-03-07 23:39:59.863      0.0      4641498.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   2.0           NaN       126       128         0       126
# 2                   0.0           NaN       126       139         0       126
# 3                   0.0           NaN       126       142         0       126
# 4                   0.0           NaN       126       143         0       126
# ...                 ...           ...       ...       ...       ...       ...
# 1464091             4.0           NaN  28917880  28918051         1  28917880
# 1464092             0.0           NaN  28797939  28919123         0  28797939
# 1464093             0.0           NaN  27829303  28920032         0  27829303
# 1464094             1.0           NaN  28921975  28922084         1  28921975
# 1464095             0.0           NaN  28902509  28921393         0  28902509
#
#          ... Closed_Q  timeDiffrence(Hours)  #answers_A  accepted_ratio_A  \
# 0        ...        1              0.054889           5          0.600000
# 1        ...        1              0.142856           4          0.000000
# 2        ...        1              0.550244           3          0.000000
# 3        ...        1              0.773842           2          0.000000
# 4        ...        1              0.849233          26          0.192308
# ...      ...      ...                   ...         ...               ...
# 1464091  ...        0              0.256716           1          1.000000
# 1464092  ...        0            144.329540           1          0.000000
# 1464093  ...        0           1415.272277           1          0.000000
# 1464094  ...        0              0.270579           4          0.250000
# 1464095  ...        0             31.761906           1          0.000000
#
#          corrected_accepted_ratio_A #answers_Q  Less_Time_Diff_Count  \
# 0                              0.50         18                     0
# 1                              0.00         18                     1
# 2                              0.00         18                     2
# 3                              0.00         18                     3
# 4                              0.20         18                     4
# ...                             ...        ...                   ...
# 1464091                        0.31          1                     0
# 1464092                        0.31          1                     0
# 1464093                        0.31          1                     0
# 1464094                        0.00          1                     0
# 1464095                        0.31          1                     0
#
#          #answers_Q_U  accepted_ratio_Q  corrected_accepted_ratio_Q
# 0                  40               0.2                    0.179487
# 1                  40               0.2                    0.205128
# 2                  40               0.2                    0.205128
# 3                  40               0.2                    0.205128
# 4                  40               0.2                    0.205128
# ...               ...               ...                         ...
# 1464091             1               1.0                    0.300000
# 1464092             1               0.0                    0.300000
# 1464093             1               0.0                    0.300000
# 1464094             1               1.0                    0.300000
# 1464095             1               0.0                    0.300000
#
# [1464096 rows x 34 columns]

# %%
tags
# Out:
#                Id               Tags
# 0         2288942     user-interface
# 1         4433442             canvas
# 2         6381190           shortcut
# 3        27466868           jboss7.x
# 4         8375328               math
# ...           ...                ...
# 1857223  17005168  google-app-engine
# 1857224  13951950   quartz-scheduler
# 1857225   7608540       jasperserver
# 1857226  20188163            barcode
# 1857227  20986566             height
#
# [1857228 rows x 2 columns]

# %%
questions.columns
# Out:
# Index(['Id', 'CreationDate', 'Score', 'ViewCount', 'OwnerUserId',
#        'CommentCount', 'ClosedDate', 'FavoriteCount'],
#       dtype='object')

# %%
len(tags['Id'].unique())
# Out:
# 762142

# %%
len(questions['Id'].unique())
# Out:
# 810071

# %%
merged_Q_A = pd.merge(questions, Q_A,  left_on='Id', right_on='QId', how='inner')
merged_Q_A
# Out:
#                Id         CreationDate  Score  ViewCount  OwnerUserId  \
# 0             123  2008-08-01 16:08:52     48      44161         78.0
# 1             123  2008-08-01 16:08:52     48      44161         78.0
# 2             123  2008-08-01 16:08:52     48      44161         78.0
# 3             123  2008-08-01 16:08:52     48      44161         78.0
# 4             123  2008-08-01 16:08:52     48      44161         78.0
# ...           ...                  ...    ...        ...          ...
# 1599710  28922872  2015-03-08 03:53:09      0         15    4113542.0
# 1599711  28922876  2015-03-08 03:53:56      0         12    4173663.0
# 1599712  28922893  2015-03-08 03:56:29      0          5    4638720.0
# 1599713  28922910  2015-03-08 03:58:22      0          4    3681742.0
# 1599714  28922922  2015-03-08 04:00:34      0          2    1029420.0
#
#          CommentCount           ClosedDate  FavoriteCount       QId       AId  \
# 0                   3                  NaN             13       123       183
# 1                   3                  NaN             13       123     53547
# 2                   3                  NaN             13       123  16483567
# 3                   3                  NaN             13       123      6726
# 4                   3                  NaN             13       123     21413
# ...               ...                  ...            ...       ...       ...
# 1599710             0                  NaN              0  28922872  28922900
# 1599711             1  2015-03-08 04:04:17              0  28922876  28922943
# 1599712             0                  NaN              0  28922893        -1
# 1599713             1                  NaN              0  28922910        -1
# 1599714             0                  NaN              0  28922922        -1
#
#          accepted
# 0               1
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1599710         0
# 1599711         0
# 1599712         0
# 1599713         0
# 1599714         0
#
# [1599715 rows x 11 columns]

# %%
merged_Q_A_tag = pd.merge(tags, merged_Q_A,  left_on='Id', right_on='Id', how='left')
merged_Q_A_tag
# Out:
#                Id            Tags         CreationDate  Score  ViewCount  \
# 0         2288942  user-interface  2010-02-18 13:41:10      2        999
# 1         2288942  user-interface  2010-02-18 13:41:10      2        999
# 2         4433442          canvas  2010-12-13 20:59:15      0        170
# 3         4433442          canvas  2010-12-13 20:59:15      0        170
# 4         6381190        shortcut  2011-06-17 04:00:39      1        938
# ...           ...             ...                  ...    ...        ...
# 3478571   7608540    jasperserver  2011-09-30 09:38:05      0       1111
# 3478572  20188163         barcode  2013-11-25 08:50:07      0        101
# 3478573  20986566          height  2014-01-08 03:38:12      3        646
# 3478574  20986566          height  2014-01-08 03:38:12      3        646
# 3478575  20986566          height  2014-01-08 03:38:12      3        646
#
#          OwnerUserId  CommentCount ClosedDate  FavoriteCount       QId  \
# 0           146588.0             1        NaN              1   2288942
# 1           146588.0             1        NaN              1   2288942
# 2           541010.0             1        NaN              0   4433442
# 3           541010.0             1        NaN              0   4433442
# 4           796580.0             1        NaN              1   6381190
# ...              ...           ...        ...            ...       ...
# 3478571     674699.0             0        NaN              0   7608540
# 3478572    1472060.0             2        NaN              0  20188163
# 3478573     592832.0             0        NaN              1  20986566
# 3478574     592832.0             0        NaN              1  20986566
# 3478575     592832.0             0        NaN              1  20986566
#
#               AId  accepted
# 0         2289065         1
# 1         2289071         0
# 2         4433475         0
# 3         4464293         0
# 4         6381550         1
# ...           ...       ...
# 3478571   7608697         0
# 3478572        -1         0
# 3478573  20997256         1
# 3478574  28554264         0
# 3478575  21000964         0
#
# [3478576 rows x 12 columns]

# %%
df_tag = merged_Q_A_tag.groupby('Tags')['accepted'].mean().reset_index(name='accepted_ratio_tag')
df_tag
# Out:
#                 Tags  accepted_ratio_tag
# 0                 .a            1.000000
# 1               .app            0.321429
# 2      .bash-profile            0.333333
# 3        .class-file            0.296992
# 4               .doc            0.217391
# ...              ...                 ...
# 18949         zpl-ii            0.333333
# 18950            zsh            0.571429
# 18951          zsync            0.000000
# 18952            zul            0.550000
# 18953          zxing            0.314024
#
# [18954 rows x 2 columns]

# %%
df_tag2 = merged_Q_A_tag.groupby('Tags').size().reset_index(name='#tag')
df_tag2
# Out:
#                 Tags  #tag
# 0                 .a     1
# 1               .app    28
# 2      .bash-profile    12
# 3        .class-file   266
# 4               .doc    23
# ...              ...   ...
# 18949         zpl-ii     6
# 18950            zsh     7
# 18951          zsync     1
# 18952            zul    40
# 18953          zxing   328
#
# [18954 rows x 2 columns]

# %%
merged_tag = pd.merge(df_tag, df_tag2,  left_on='Tags', right_on='Tags', how='inner')
merged_tag.loc[merged_tag['#tag']<10, 'accepted_ratio_tag'] = np.nan   #we ignore ratio for tags with few occurrence
merged_tag
# Out:
#                 Tags  accepted_ratio_tag  #tag
# 0                 .a                 NaN     1
# 1               .app            0.321429    28
# 2      .bash-profile            0.333333    12
# 3        .class-file            0.296992   266
# 4               .doc            0.217391    23
# ...              ...                 ...   ...
# 18949         zpl-ii                 NaN     6
# 18950            zsh                 NaN     7
# 18951          zsync                 NaN     1
# 18952            zul            0.550000    40
# 18953          zxing            0.314024   328
#
# [18954 rows x 3 columns]

# %%
mean_value = merged_tag['accepted_ratio_tag'].mean()
merged_tag['accepted_ratio_tag'].fillna(round(mean_value, 2), inplace=True)
merged_tag
# Out:
#                 Tags  accepted_ratio_tag  #tag
# 0                 .a            0.300000     1
# 1               .app            0.321429    28
# 2      .bash-profile            0.333333    12
# 3        .class-file            0.296992   266
# 4               .doc            0.217391    23
# ...              ...                 ...   ...
# 18949         zpl-ii            0.300000     6
# 18950            zsh            0.300000     7
# 18951          zsync            0.300000     1
# 18952            zul            0.550000    40
# 18953          zxing            0.314024   328
#
# [18954 rows x 3 columns]

# %%
merged_Q_A_tag2 = pd.merge(merged_Q_A_tag, merged_tag,  left_on='Tags', right_on='Tags', how='left')
merged_Q_A_tag2
# Out:
#                Id            Tags         CreationDate  Score  ViewCount  \
# 0         2288942  user-interface  2010-02-18 13:41:10      2        999
# 1         2288942  user-interface  2010-02-18 13:41:10      2        999
# 2         4433442          canvas  2010-12-13 20:59:15      0        170
# 3         4433442          canvas  2010-12-13 20:59:15      0        170
# 4         6381190        shortcut  2011-06-17 04:00:39      1        938
# ...           ...             ...                  ...    ...        ...
# 3478571   7608540    jasperserver  2011-09-30 09:38:05      0       1111
# 3478572  20188163         barcode  2013-11-25 08:50:07      0        101
# 3478573  20986566          height  2014-01-08 03:38:12      3        646
# 3478574  20986566          height  2014-01-08 03:38:12      3        646
# 3478575  20986566          height  2014-01-08 03:38:12      3        646
#
#          OwnerUserId  CommentCount ClosedDate  FavoriteCount       QId  \
# 0           146588.0             1        NaN              1   2288942
# 1           146588.0             1        NaN              1   2288942
# 2           541010.0             1        NaN              0   4433442
# 3           541010.0             1        NaN              0   4433442
# 4           796580.0             1        NaN              1   6381190
# ...              ...           ...        ...            ...       ...
# 3478571     674699.0             0        NaN              0   7608540
# 3478572    1472060.0             2        NaN              0  20188163
# 3478573     592832.0             0        NaN              1  20986566
# 3478574     592832.0             0        NaN              1  20986566
# 3478575     592832.0             0        NaN              1  20986566
#
#               AId  accepted  accepted_ratio_tag     #tag
# 0         2289065         1            0.315374  14329.0
# 1         2289071         0            0.315374  14329.0
# 2         4433475         0            0.351275    706.0
# 3         4464293         0            0.351275    706.0
# 4         6381550         1            0.284211    190.0
# ...           ...       ...                 ...      ...
# 3478571   7608697         0            0.290323    124.0
# 3478572        -1         0            0.262458    301.0
# 3478573  20997256         1            0.319588     97.0
# 3478574  28554264         0            0.319588     97.0
# 3478575  21000964         0            0.319588     97.0
#
# [3478576 rows x 14 columns]

# %%
df2 = merged_Q_A_tag2.groupby('QId')['accepted_ratio_tag'].mean().reset_index(name='accepted_ratio_tags_mean')
df2
# Out:
#              QId  accepted_ratio_tags_mean
# 0            123                  0.270820
# 1            126                  0.237437
# 2            382                  0.291427
# 3            564                  0.223217
# 4           2092                  0.277343
# ...          ...                       ...
# 762137  28922872                  0.295652
# 762138  28922876                  0.276910
# 762139  28922893                  0.319926
# 762140  28922910                  0.339874
# 762141  28922922                  0.273407
#
# [762142 rows x 2 columns]

# %%
df3 = tags.groupby('Id').size().reset_index(name='#tags_Q')
df3
# Out:
#               Id  #tags_Q
# 0            123        3
# 1            126        3
# 2            382        4
# 3            564        3
# 4           2092        3
# ...          ...      ...
# 762137  28922872        1
# 762138  28922876        2
# 762139  28922893        3
# 762140  28922910        3
# 762141  28922922        2
#
# [762142 rows x 2 columns]

# %%
merged_df = pd.merge(df2, df3,  left_on='QId', right_on='Id', how='inner')
merged_df
# Out:
#              QId  accepted_ratio_tags_mean        Id  #tags_Q
# 0            123                  0.270820       123        3
# 1            126                  0.237437       126        3
# 2            382                  0.291427       382        4
# 3            564                  0.223217       564        3
# 4           2092                  0.277343      2092        3
# ...          ...                       ...       ...      ...
# 762137  28922872                  0.295652  28922872        1
# 762138  28922876                  0.276910  28922876        2
# 762139  28922893                  0.319926  28922893        3
# 762140  28922910                  0.339874  28922910        3
# 762141  28922922                  0.273407  28922922        2
#
# [762142 rows x 4 columns]

# %%
merged_A_Q_U_B2_R5 = pd.merge(merged_A_Q_U_B2_R4, merged_df,  left_on='QId', right_on='QId', how='left')
merged_A_Q_U_B2_R5
# Out:
#              Id_A          CreationDate_A  Score_A  OwnerUserId_A  \
# 0             127 2008-08-01 16:13:47.600     37.0           35.0
# 1             128 2008-08-01 16:19:04.283      7.0           26.0
# 2             139 2008-08-01 16:43:30.880      5.0           72.0
# 3             142 2008-08-01 16:56:55.830      2.0           42.0
# 4             143 2008-08-01 17:01:27.240      3.0           86.0
# ...           ...                     ...      ...            ...
# 1464091  28918051 2015-03-07 17:51:24.177      2.0      4638142.0
# 1464092  28919123 2015-03-07 19:39:56.343      0.0      3718088.0
# 1464093  28920032 2015-03-07 21:10:08.197      1.0      2641836.0
# 1464094  28922084 2015-03-08 01:24:30.083      1.0      4645110.0
# 1464095  28921393 2015-03-07 23:39:59.863      0.0      4641498.0
#
#          CommentCount_A  ClosedDate_A       QId       AId  accepted      Id_Q  \
# 0                   2.0           NaN       126       127         1       126
# 1                   2.0           NaN       126       128         0       126
# 2                   0.0           NaN       126       139         0       126
# 3                   0.0           NaN       126       142         0       126
# 4                   0.0           NaN       126       143         0       126
# ...                 ...           ...       ...       ...       ...       ...
# 1464091             4.0           NaN  28917880  28918051         1  28917880
# 1464092             0.0           NaN  28797939  28919123         0  28797939
# 1464093             0.0           NaN  27829303  28920032         0  27829303
# 1464094             1.0           NaN  28921975  28922084         1  28921975
# 1464095             0.0           NaN  28902509  28921393         0  28902509
#
#          ... accepted_ratio_A  corrected_accepted_ratio_A  #answers_Q  \
# 0        ...         0.600000                        0.50          18
# 1        ...         0.000000                        0.00          18
# 2        ...         0.000000                        0.00          18
# 3        ...         0.000000                        0.00          18
# 4        ...         0.192308                        0.20          18
# ...      ...              ...                         ...         ...
# 1464091  ...         1.000000                        0.31           1
# 1464092  ...         0.000000                        0.31           1
# 1464093  ...         0.000000                        0.31           1
# 1464094  ...         0.250000                        0.00           1
# 1464095  ...         0.000000                        0.31           1
#
#          Less_Time_Diff_Count  #answers_Q_U accepted_ratio_Q  \
# 0                           0            40              0.2
# 1                           1            40              0.2
# 2                           2            40              0.2
# 3                           3            40              0.2
# 4                           4            40              0.2
# ...                       ...           ...              ...
# 1464091                     0             1              1.0
# 1464092                     0             1              0.0
# 1464093                     0             1              0.0
# 1464094                     0             1              1.0
# 1464095                     0             1              0.0
#
#          corrected_accepted_ratio_Q  accepted_ratio_tags_mean        Id_y  \
# 0                          0.179487                  0.237437       126.0
# 1                          0.205128                  0.237437       126.0
# 2                          0.205128                  0.237437       126.0
# 3                          0.205128                  0.237437       126.0
# 4                          0.205128                  0.237437       126.0
# ...                             ...                       ...         ...
# 1464091                    0.300000                  0.344976  28917880.0
# 1464092                    0.300000                  0.319451  28797939.0
# 1464093                    0.300000                  0.320470  27829303.0
# 1464094                    0.300000                  0.302232  28921975.0
# 1464095                    0.300000                  0.239039  28902509.0
#
#          #tags_Q
# 0            3.0
# 1            3.0
# 2            3.0
# 3            3.0
# 4            3.0
# ...          ...
# 1464091      2.0
# 1464092      3.0
# 1464093      4.0
# 1464094      3.0
# 1464095      4.0
#
# [1464096 rows x 37 columns]

# %%
merged_A_Q_U_B2_R5.columns
# Out:
# Index(['Id_A', 'CreationDate_A', 'Score_A', 'OwnerUserId_A', 'CommentCount_A',
#        'ClosedDate_A', 'QId', 'AId', 'accepted', 'Id_Q', 'CreationDate_Q',
#        'Score_Q', 'ViewCount', 'OwnerUserId_Q', 'CommentCount_Q',
#        'ClosedDate_Q', 'FavoriteCount', 'Id_x', 'Reputation', 'Views',
#        'UpVotes', 'DownVotes', 'UserId', 'badgeCount', 'Closed_Q',
#        'timeDiffrence(Hours)', '#answers_A', 'accepted_ratio_A',
#        'corrected_accepted_ratio_A', '#answers_Q', 'Less_Time_Diff_Count',
#        '#answers_Q_U', 'accepted_ratio_Q', 'corrected_accepted_ratio_Q',
#        'accepted_ratio_tags_mean', 'Id_y', '#tags_Q'],
#       dtype='object')

# %%
merged_A_Q_U_B2_R6 = merged_A_Q_U_B2_R5.drop(columns=['Id_A','CreationDate_A','OwnerUserId_A','ClosedDate_A','QId','AId','Id_Q','CreationDate_Q','OwnerUserId_Q','ClosedDate_Q','Id_x','UserId','#answers_A','accepted_ratio_A','#answers_Q_U','accepted_ratio_Q','Id_y'], inplace=False)
merged_A_Q_U_B2_R6
# Out:
#          Score_A  CommentCount_A  accepted  Score_Q  ViewCount  \
# 0           37.0             2.0         1       33       6357
# 1            7.0             2.0         0       33       6357
# 2            5.0             0.0         0       33       6357
# 3            2.0             0.0         0       33       6357
# 4            3.0             0.0         0       33       6357
# ...          ...             ...       ...      ...        ...
# 1464091      2.0             4.0         1        0         10
# 1464092      0.0             0.0         0        0         19
# 1464093      1.0             0.0         0        1        103
# 1464094      1.0             1.0         1       -1         15
# 1464095      0.0             0.0         0        0         34
#
#          CommentCount_Q  FavoriteCount  Reputation  Views  UpVotes  DownVotes  \
# 0                     0              2       11543   1060      436        208
# 1                     0              2        8520   2843      564         67
# 2                     0              2       18882   1118     1168         21
# 3                     0              2       13820    754      359         45
# 4                     0              2        3578    366     1641         59
# ...                 ...            ...         ...    ...      ...        ...
# 1464091               0              0          36      1       10          0
# 1464092               0              0          14     17        0          0
# 1464093               2              0          16     50        0          0
# 1464094               1              0          26      0        0          0
# 1464095               2              0           1      0        0          0
#
#          badgeCount  Closed_Q  timeDiffrence(Hours)  \
# 0               113         1              0.054889
# 1               212         1              0.142856
# 2               160         1              0.550244
# 3                92         1              0.773842
# 4                73         1              0.849233
# ...             ...       ...                   ...
# 1464091           4         0              0.256716
# 1464092           5         0            144.329540
# 1464093           4         0           1415.272277
# 1464094           3         0              0.270579
# 1464095           2         0             31.761906
#
#          corrected_accepted_ratio_A  #answers_Q  Less_Time_Diff_Count  \
# 0                              0.50          18                     0
# 1                              0.00          18                     1
# 2                              0.00          18                     2
# 3                              0.00          18                     3
# 4                              0.20          18                     4
# ...                             ...         ...                   ...
# 1464091                        0.31           1                     0
# 1464092                        0.31           1                     0
# 1464093                        0.31           1                     0
# 1464094                        0.00           1                     0
# 1464095                        0.31           1                     0
#
#          corrected_accepted_ratio_Q  accepted_ratio_tags_mean  #tags_Q
# 0                          0.179487                  0.237437      3.0
# 1                          0.205128                  0.237437      3.0
# 2                          0.205128                  0.237437      3.0
# 3                          0.205128                  0.237437      3.0
# 4                          0.205128                  0.237437      3.0
# ...                             ...                       ...      ...
# 1464091                    0.300000                  0.344976      2.0
# 1464092                    0.300000                  0.319451      3.0
# 1464093                    0.300000                  0.320470      4.0
# 1464094                    0.300000                  0.302232      3.0
# 1464095                    0.300000                  0.239039      4.0
#
# [1464096 rows x 20 columns]

# %%
len(merged_A_Q_U_B2_R6[merged_A_Q_U_B2_R6['accepted']==1])
# Out:
# 445570

# %%
len(merged_A_Q_U_B2_R6[merged_A_Q_U_B2_R6['accepted']==0])
# Out:
# 1018526

# %%
merged_A_Q_U_B2_R6.corr()['accepted']
# Out:
# Score_A                       0.060563
# CommentCount_A                0.185560
# accepted                      1.000000
# Score_Q                      -0.035970
# ViewCount                    -0.053804
# CommentCount_Q               -0.046931
# FavoriteCount                -0.028629
# Reputation                    0.106922
# Views                         0.062892
# UpVotes                       0.093185
# DownVotes                     0.072952
# badgeCount                    0.075717
# Closed_Q                     -0.035723
# timeDiffrence(Hours)         -0.127006
# corrected_accepted_ratio_A    0.190970
# #answers_Q                   -0.240192
# Less_Time_Diff_Count         -0.209611
# corrected_accepted_ratio_Q    0.092289
# accepted_ratio_tags_mean      0.154605
# #tags_Q                       0.044334
# Name: accepted, dtype: float64

# %%
# Calculate correlation matrix
correlation_matrix = merged_A_Q_U_B2_R6.corr()

fig = plt.figure(figsize=(15,15))

fig.patch.set_facecolor('None')
#fig.patch.set_alpha(0.7)

heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap (Questions)')

# Set the background of the plot to be transparent
heatmap.patch.set_facecolor('none')
heatmap.patch.set_alpha(0.1)
plt.show()

# %% [markdown]
# # Create dataset splits

# %%
features = merged_A_Q_U_B2_R6.drop(["accepted"], axis=1)
labels = merged_A_Q_U_B2_R6["accepted"]

# %%
train_X, val_X, train_y, val_y = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
train_X.columns
# Out:
# Index(['Score_A', 'CommentCount_A', 'Score_Q', 'ViewCount', 'CommentCount_Q',
#        'FavoriteCount', 'Reputation', 'Views', 'UpVotes', 'DownVotes',
#        'badgeCount', 'Closed_Q', 'timeDiffrence(Hours)',
#        'corrected_accepted_ratio_A', '#answers_Q', 'Less_Time_Diff_Count',
#        'corrected_accepted_ratio_Q', 'accepted_ratio_tags_mean', '#tags_Q'],
#       dtype='object')

# %% [markdown]
# # Model (XGBOOST)

# %%
# Define the XGBoost classifier
xgb_classifier = xgb.XGBClassifier(
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method='hist',
    use_label_encoder=False,
    nthread=-1,
    seed=42,
)

# %% [markdown]
# # Training

# %%
# Train the XGBoost classifier
xgb_classifier.fit(train_X, train_y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, nthread=-1, num_parallel_tree=None, ...)

# %% [markdown]
# # Evalutation

# %%
# Make predictions on the validation set
val_predictions = xgb_classifier.predict(val_X)

# Evaluate the performance on the validation set
accuracy = metrics.accuracy_score(val_y, val_predictions)
print(f'Accuracy on the validation set: {accuracy:.2f}')


accuracy = metrics.f1_score(val_y, val_predictions)
print(f'F1 on the validation set: {accuracy:.2f}')

accuracy = metrics.precision_score(val_y, val_predictions)
print(f'Precision on the validation set: {accuracy:.2f}')

accuracy = metrics.recall_score(val_y, val_predictions)
print(f'Recall on the validation set: {accuracy:.2f}')

# Print classification report for more detailed evaluation
print('\nClassification Report:\n', metrics.classification_report(val_y, val_predictions))
# Out:
# Accuracy on the validation set: 0.82
# F1 on the validation set: 0.69
# Precision on the validation set: 0.75
# Recall on the validation set: 0.63
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88    203789
#            1       0.75      0.63      0.69     89031
#
#     accuracy                           0.82    292820
#    macro avg       0.80      0.77      0.78    292820
# weighted avg       0.82      0.82      0.82    292820

# %% [markdown]
# # Feature importance

# %%
import matplotlib.pyplot as plt

xgb.plot_importance(xgb_classifier)
plt.show()
